# %%
import torch
import torchvision
from torchvision import transforms

import numpy as np 
import matplotlib.pyplot as plt
from PIL import Image

# %%
from torch.utils.data import Dataset
import numpy as np
import random
import cv2
import h5py

class TrainDataset(Dataset):
    def __init__(self, data_root, target_size=(512, 512), bgr2rgb=True):
        self.hypers = []
        self.bgrs = []
        hyper_data_path = f'{data_root}/Train_spectral/'
        bgr_data_path = f'{data_root}/Train_RGB/'
        with open(f'{data_root}/split_txt/Train_list.txt', 'r') as fin:
            hyper_list = [line.replace('\n', '.mat') for line in fin]
            bgr_list = [line.replace('mat','jpg') for line in hyper_list]
        hyper_list.sort()
        bgr_list.sort()
        print(f'len(hyper_Train) of ntire2022 dataset:{len(hyper_list)}')
        print(f'len(bgr_Train) of ntire2022 dataset:{len(bgr_list)}')
        for i in range(len(hyper_list)):
            hyper_path = hyper_data_path + hyper_list[i]
            if 'mat' not in hyper_path:
                continue
            with h5py.File(hyper_path, 'r') as mat:
                hyper = np.float32(np.array(mat['cube']))
            hyper = np.transpose(hyper, [0, 2, 1])
            bgr_path = bgr_data_path + bgr_list[i]
            assert hyper_list[i].split('.')[0] == bgr_list[i].split('.')[0], 'Hyper and RGB come from different scenes.'
            bgr = cv2.imread(bgr_path)
            if bgr2rgb:
                bgr = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)
            bgr = np.float32(bgr)
            bgr = (bgr - bgr.min()) / (bgr.max() - bgr.min())
            bgr = np.transpose(bgr, [2, 0, 1])
            self.hypers.append(hyper)
            self.bgrs.append(bgr)
            mat.close()
            print(f'Ntire2022 scene {i} is loaded.')

    def __getitem__(self, idx):
        hyper = self.hypers[idx]
        bgr = self.bgrs[idx]
        target_size = (512,512)
        # Resize both hyper and bgr images to the target size
        hyper = cv2.resize(hyper.transpose(1, 2, 0), target_size).transpose(2, 0, 1)
        bgr = cv2.resize(bgr.transpose(1, 2, 0), target_size).transpose(2, 0, 1)
        
        return np.ascontiguousarray(bgr), np.ascontiguousarray(hyper)

    def __len__(self):
        return len(self.hypers)

class ValidDataset(Dataset):
    def __init__(self, data_root, target_size=(512, 512), bgr2rgb=True):
        self.hypers = []
        self.bgrs = []
        hyper_data_path = f'{data_root}/Valid_spectral/'
        bgr_data_path = f'{data_root}/Valid_RGB/'
        with open(f'{data_root}/split_txt/valid_list.txt', 'r') as fin:
            hyper_list = [line.replace('\n', '.mat') for line in fin]
            bgr_list = [line.replace('mat','jpg') for line in hyper_list]
        hyper_list.sort()
        bgr_list.sort()
        print(f'len(hyper_valid) of ntire2022 dataset:{len(hyper_list)}')
        print(f'len(bgr_valid) of ntire2022 dataset:{len(bgr_list)}')
        for i in range(len(hyper_list)):
            hyper_path = hyper_data_path + hyper_list[i]
            if 'mat' not in hyper_path:
                continue
            with h5py.File(hyper_path, 'r') as mat:
                hyper = np.float32(np.array(mat['cube']))
            hyper = np.transpose(hyper, [0, 2, 1])
            bgr_path = bgr_data_path + bgr_list[i]
            assert hyper_list[i].split('.')[0] == bgr_list[i].split('.')[0], 'Hyper and RGB come from different scenes.'
            bgr = cv2.imread(bgr_path)
            if bgr2rgb:
                bgr = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)
            bgr = np.float32(bgr)
            bgr = (bgr - bgr.min()) / (bgr.max() - bgr.min())
            bgr = np.transpose(bgr, [2, 0, 1])
            self.hypers.append(hyper)
            self.bgrs.append(bgr)
            mat.close()
            print(f'Ntire2022 scene {i} is loaded.')

    def __getitem__(self, idx):
        hyper = self.hypers[idx]
        bgr = self.bgrs[idx]
#         print(hyper.shape)
        
        target_size = (512,512)
        # Resize both hyper and bgr images to the target size
        hyper = cv2.resize(hyper.transpose(1, 2, 0), target_size).transpose(2, 0, 1)
        bgr = cv2.resize(bgr.transpose(1, 2, 0), target_size).transpose(2, 0, 1)
#         print(hyper.shape)
        return np.ascontiguousarray(bgr), np.ascontiguousarray(hyper)

    def __len__(self):
        return len(self.hypers)

# %%
from torch.utils.data import DataLoader

# Define the dataset path
data_root = "C:/Users/user/Desktop/Research/Datasets/Manual_split_NTIRE_2022"

# Create instances of TrainDataset and ValidDataset
train_dataset = TrainDataset(data_root=data_root, bgr2rgb=True)
valid_dataset = ValidDataset(data_root=data_root, bgr2rgb=True)

# Create DataLoader instances for both datasets
train_loader = DataLoader(dataset=train_dataset, batch_size=1, shuffle=True)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=1, shuffle=False)

# Load one batch of data from each DataLoader
train_images, train_labels = next(iter(train_loader))
valid_images, valid_labels = next(iter(valid_loader))

# Print the shapes of the loaded data
print("Train Images Shape:", train_images.shape)
print("Train Labels Shape:", train_labels.shape)
print("Valid Images Shape:", valid_images.shape)
print("Valid Labels Shape:", valid_labels.shape)
# Out:
# len(hyper_Train) of ntire2022 dataset:797
# len(bgr_Train) of ntire2022 dataset:797
# Ntire2022 scene 0 is loaded.
# Ntire2022 scene 1 is loaded.
# Ntire2022 scene 2 is loaded.
# Ntire2022 scene 3 is loaded.
# Ntire2022 scene 4 is loaded.
# Ntire2022 scene 5 is loaded.
# Ntire2022 scene 6 is loaded.
# Ntire2022 scene 7 is loaded.
# Ntire2022 scene 8 is loaded.
# Ntire2022 scene 9 is loaded.
# Ntire2022 scene 10 is loaded.
# Ntire2022 scene 11 is loaded.
# Ntire2022 scene 12 is loaded.
# Ntire2022 scene 13 is loaded.
# Ntire2022 scene 14 is loaded.
# Ntire2022 scene 15 is loaded.
# Ntire2022 scene 16 is loaded.
# Ntire2022 scene 17 is loaded.
# Ntire2022 scene 18 is loaded.
# Ntire2022 scene 19 is loaded.
# Ntire2022 scene 20 is loaded.
# Ntire2022 scene 21 is loaded.
# Ntire2022 scene 22 is loaded.
# Ntire2022 scene 23 is loaded.
# Ntire2022 scene 24 is loaded.
# Ntire2022 scene 25 is loaded.
# Ntire2022 scene 26 is loaded.
# Ntire2022 scene 27 is loaded.
# Ntire2022 scene 28 is loaded.
# Ntire2022 scene 29 is loaded.
# Ntire2022 scene 30 is loaded.
# Ntire2022 scene 31 is loaded.
# Ntire2022 scene 32 is loaded.
# Ntire2022 scene 33 is loaded.
# Ntire2022 scene 34 is loaded.
# Ntire2022 scene 35 is loaded.
# Ntire2022 scene 36 is loaded.
# Ntire2022 scene 37 is loaded.
# Ntire2022 scene 38 is loaded.
# Ntire2022 scene 39 is loaded.
# Ntire2022 scene 40 is loaded.
# Ntire2022 scene 41 is loaded.
# Ntire2022 scene 42 is loaded.
# Ntire2022 scene 43 is loaded.
# Ntire2022 scene 44 is loaded.
# Ntire2022 scene 45 is loaded.
# Ntire2022 scene 46 is loaded.
# Ntire2022 scene 47 is loaded.
# Ntire2022 scene 48 is loaded.
# Ntire2022 scene 49 is loaded.
# Ntire2022 scene 50 is loaded.
# Ntire2022 scene 51 is loaded.
# Ntire2022 scene 52 is loaded.
# Ntire2022 scene 53 is loaded.
# Ntire2022 scene 54 is loaded.
# Ntire2022 scene 55 is loaded.
# Ntire2022 scene 56 is loaded.
# Ntire2022 scene 57 is loaded.
# Ntire2022 scene 58 is loaded.
# Ntire2022 scene 59 is loaded.
# Ntire2022 scene 60 is loaded.
# Ntire2022 scene 61 is loaded.
# Ntire2022 scene 62 is loaded.
# Ntire2022 scene 63 is loaded.
# Ntire2022 scene 64 is loaded.
# Ntire2022 scene 65 is loaded.
# Ntire2022 scene 66 is loaded.
# Ntire2022 scene 67 is loaded.
# Ntire2022 scene 68 is loaded.
# Ntire2022 scene 69 is loaded.
# Ntire2022 scene 70 is loaded.
# Ntire2022 scene 71 is loaded.
# Ntire2022 scene 72 is loaded.
# Ntire2022 scene 73 is loaded.
# Ntire2022 scene 74 is loaded.
# Ntire2022 scene 75 is loaded.
# Ntire2022 scene 76 is loaded.
# Ntire2022 scene 77 is loaded.
# Ntire2022 scene 78 is loaded.
# Ntire2022 scene 79 is loaded.
# Ntire2022 scene 80 is loaded.
# Ntire2022 scene 81 is loaded.
# Ntire2022 scene 82 is loaded.
# Ntire2022 scene 83 is loaded.
# Ntire2022 scene 84 is loaded.
# Ntire2022 scene 85 is loaded.
# Ntire2022 scene 86 is loaded.
# Ntire2022 scene 87 is loaded.
# Ntire2022 scene 88 is loaded.
# Ntire2022 scene 89 is loaded.
# Ntire2022 scene 90 is loaded.
# Ntire2022 scene 91 is loaded.
# Ntire2022 scene 92 is loaded.
# Ntire2022 scene 93 is loaded.
# Ntire2022 scene 94 is loaded.
# Ntire2022 scene 95 is loaded.
# Ntire2022 scene 96 is loaded.
# Ntire2022 scene 97 is loaded.
# Ntire2022 scene 98 is loaded.
# Ntire2022 scene 99 is loaded.
# Ntire2022 scene 100 is loaded.
# Ntire2022 scene 101 is loaded.
# Ntire2022 scene 102 is loaded.
# Ntire2022 scene 103 is loaded.
# Ntire2022 scene 104 is loaded.
# Ntire2022 scene 105 is loaded.
# Ntire2022 scene 106 is loaded.
# Ntire2022 scene 107 is loaded.
# Ntire2022 scene 108 is loaded.
# Ntire2022 scene 109 is loaded.
# Ntire2022 scene 110 is loaded.
# Ntire2022 scene 111 is loaded.
# Ntire2022 scene 112 is loaded.
# Ntire2022 scene 113 is loaded.
# Ntire2022 scene 114 is loaded.
# Ntire2022 scene 115 is loaded.
# Ntire2022 scene 116 is loaded.
# Ntire2022 scene 117 is loaded.
# Ntire2022 scene 118 is loaded.
# Ntire2022 scene 119 is loaded.
# Ntire2022 scene 120 is loaded.
# Ntire2022 scene 121 is loaded.
# Ntire2022 scene 122 is loaded.
# Ntire2022 scene 123 is loaded.
# Ntire2022 scene 124 is loaded.
# Ntire2022 scene 125 is loaded.
# Ntire2022 scene 126 is loaded.
# Ntire2022 scene 127 is loaded.
# Ntire2022 scene 128 is loaded.
# Ntire2022 scene 129 is loaded.
# Ntire2022 scene 130 is loaded.
# Ntire2022 scene 131 is loaded.
# Ntire2022 scene 132 is loaded.
# Ntire2022 scene 133 is loaded.
# Ntire2022 scene 134 is loaded.
# Ntire2022 scene 135 is loaded.
# Ntire2022 scene 136 is loaded.
# Ntire2022 scene 137 is loaded.
# Ntire2022 scene 138 is loaded.
# Ntire2022 scene 139 is loaded.
# Ntire2022 scene 140 is loaded.
# Ntire2022 scene 141 is loaded.
# Ntire2022 scene 142 is loaded.
# Ntire2022 scene 143 is loaded.
# Ntire2022 scene 144 is loaded.
# Ntire2022 scene 145 is loaded.
# Ntire2022 scene 146 is loaded.
# Ntire2022 scene 147 is loaded.
# Ntire2022 scene 148 is loaded.
# Ntire2022 scene 149 is loaded.
# Ntire2022 scene 150 is loaded.
# Ntire2022 scene 151 is loaded.
# Ntire2022 scene 152 is loaded.
# Ntire2022 scene 153 is loaded.
# Ntire2022 scene 154 is loaded.
# Ntire2022 scene 155 is loaded.
# Ntire2022 scene 156 is loaded.
# Ntire2022 scene 157 is loaded.
# Ntire2022 scene 158 is loaded.
# Ntire2022 scene 159 is loaded.
# Ntire2022 scene 160 is loaded.
# Ntire2022 scene 161 is loaded.
# Ntire2022 scene 162 is loaded.
# Ntire2022 scene 163 is loaded.
# Ntire2022 scene 164 is loaded.
# Ntire2022 scene 165 is loaded.
# Ntire2022 scene 166 is loaded.
# Ntire2022 scene 167 is loaded.
# Ntire2022 scene 168 is loaded.
# Ntire2022 scene 169 is loaded.
# Ntire2022 scene 170 is loaded.
# Ntire2022 scene 171 is loaded.
# Ntire2022 scene 172 is loaded.
# Ntire2022 scene 173 is loaded.
# Ntire2022 scene 174 is loaded.
# Ntire2022 scene 175 is loaded.
# Ntire2022 scene 176 is loaded.
# Ntire2022 scene 177 is loaded.
# Ntire2022 scene 178 is loaded.
# Ntire2022 scene 179 is loaded.
# Ntire2022 scene 180 is loaded.
# Ntire2022 scene 181 is loaded.
# Ntire2022 scene 182 is loaded.
# Ntire2022 scene 183 is loaded.
# Ntire2022 scene 184 is loaded.
# Ntire2022 scene 185 is loaded.
# Ntire2022 scene 186 is loaded.
# Ntire2022 scene 187 is loaded.
# Ntire2022 scene 188 is loaded.
# Ntire2022 scene 189 is loaded.
# Ntire2022 scene 190 is loaded.
# Ntire2022 scene 191 is loaded.
# Ntire2022 scene 192 is loaded.
# Ntire2022 scene 193 is loaded.
# Ntire2022 scene 194 is loaded.
# Ntire2022 scene 195 is loaded.
# Ntire2022 scene 196 is loaded.
# Ntire2022 scene 197 is loaded.
# Ntire2022 scene 198 is loaded.
# Ntire2022 scene 199 is loaded.
# Ntire2022 scene 200 is loaded.
# Ntire2022 scene 201 is loaded.
# Ntire2022 scene 202 is loaded.
# Ntire2022 scene 203 is loaded.
# Ntire2022 scene 204 is loaded.
# Ntire2022 scene 205 is loaded.
# Ntire2022 scene 206 is loaded.
# Ntire2022 scene 207 is loaded.
# Ntire2022 scene 208 is loaded.
# Ntire2022 scene 209 is loaded.
# Ntire2022 scene 210 is loaded.
# Ntire2022 scene 211 is loaded.
# Ntire2022 scene 212 is loaded.
# Ntire2022 scene 213 is loaded.
# Ntire2022 scene 214 is loaded.
# Ntire2022 scene 215 is loaded.
# Ntire2022 scene 216 is loaded.
# Ntire2022 scene 217 is loaded.
# Ntire2022 scene 218 is loaded.
# Ntire2022 scene 219 is loaded.
# Ntire2022 scene 220 is loaded.
# Ntire2022 scene 221 is loaded.
# Ntire2022 scene 222 is loaded.
# Ntire2022 scene 223 is loaded.
# Ntire2022 scene 224 is loaded.
# Ntire2022 scene 225 is loaded.
# Ntire2022 scene 226 is loaded.
# Ntire2022 scene 227 is loaded.
# Ntire2022 scene 228 is loaded.
# Ntire2022 scene 229 is loaded.
# Ntire2022 scene 230 is loaded.
# Ntire2022 scene 231 is loaded.
# Ntire2022 scene 232 is loaded.
# Ntire2022 scene 233 is loaded.
# Ntire2022 scene 234 is loaded.
# Ntire2022 scene 235 is loaded.
# Ntire2022 scene 236 is loaded.
# Ntire2022 scene 237 is loaded.
# Ntire2022 scene 238 is loaded.
# Ntire2022 scene 239 is loaded.
# Ntire2022 scene 240 is loaded.
# Ntire2022 scene 241 is loaded.
# Ntire2022 scene 242 is loaded.
# Ntire2022 scene 243 is loaded.
# Ntire2022 scene 244 is loaded.
# Ntire2022 scene 245 is loaded.
# Ntire2022 scene 246 is loaded.
# Ntire2022 scene 247 is loaded.
# Ntire2022 scene 248 is loaded.
# Ntire2022 scene 249 is loaded.
# Ntire2022 scene 250 is loaded.
# Ntire2022 scene 251 is loaded.
# Ntire2022 scene 252 is loaded.
# Ntire2022 scene 253 is loaded.
# Ntire2022 scene 254 is loaded.
# Ntire2022 scene 255 is loaded.
# Ntire2022 scene 256 is loaded.
# Ntire2022 scene 257 is loaded.
# Ntire2022 scene 258 is loaded.
# Ntire2022 scene 259 is loaded.
# Ntire2022 scene 260 is loaded.
# Ntire2022 scene 261 is loaded.
# Ntire2022 scene 262 is loaded.
# Ntire2022 scene 263 is loaded.
# Ntire2022 scene 264 is loaded.
# Ntire2022 scene 265 is loaded.
# Ntire2022 scene 266 is loaded.
# Ntire2022 scene 267 is loaded.
# Ntire2022 scene 268 is loaded.
# Ntire2022 scene 269 is loaded.
# Ntire2022 scene 270 is loaded.
# Ntire2022 scene 271 is loaded.
# Ntire2022 scene 272 is loaded.
# Ntire2022 scene 273 is loaded.
# Ntire2022 scene 274 is loaded.
# Ntire2022 scene 275 is loaded.
# Ntire2022 scene 276 is loaded.
# Ntire2022 scene 277 is loaded.
# Ntire2022 scene 278 is loaded.
# Ntire2022 scene 279 is loaded.
# Ntire2022 scene 280 is loaded.
# Ntire2022 scene 281 is loaded.
# Ntire2022 scene 282 is loaded.
# Ntire2022 scene 283 is loaded.
# Ntire2022 scene 284 is loaded.
# Ntire2022 scene 285 is loaded.
# Ntire2022 scene 286 is loaded.
# Ntire2022 scene 287 is loaded.
# Ntire2022 scene 288 is loaded.
# Ntire2022 scene 289 is loaded.
# Ntire2022 scene 290 is loaded.
# Ntire2022 scene 291 is loaded.
# Ntire2022 scene 292 is loaded.
# Ntire2022 scene 293 is loaded.
# Ntire2022 scene 294 is loaded.
# Ntire2022 scene 295 is loaded.
# Ntire2022 scene 296 is loaded.
# Ntire2022 scene 297 is loaded.
# Ntire2022 scene 298 is loaded.
# Ntire2022 scene 299 is loaded.
# Ntire2022 scene 300 is loaded.
# Ntire2022 scene 301 is loaded.
# Ntire2022 scene 302 is loaded.
# Ntire2022 scene 303 is loaded.
# Ntire2022 scene 304 is loaded.
# Ntire2022 scene 305 is loaded.
# Ntire2022 scene 306 is loaded.
# Ntire2022 scene 307 is loaded.
# Ntire2022 scene 308 is loaded.
# Ntire2022 scene 309 is loaded.
# Ntire2022 scene 310 is loaded.
# Ntire2022 scene 311 is loaded.
# Ntire2022 scene 312 is loaded.
# Ntire2022 scene 313 is loaded.
# Ntire2022 scene 314 is loaded.
# Ntire2022 scene 315 is loaded.
# Ntire2022 scene 316 is loaded.
# Ntire2022 scene 317 is loaded.
# Ntire2022 scene 318 is loaded.
# Ntire2022 scene 319 is loaded.
# Ntire2022 scene 320 is loaded.
# Ntire2022 scene 321 is loaded.
# Ntire2022 scene 322 is loaded.
# Ntire2022 scene 323 is loaded.
# Ntire2022 scene 324 is loaded.
# Ntire2022 scene 325 is loaded.
# Ntire2022 scene 326 is loaded.
# Ntire2022 scene 327 is loaded.
# Ntire2022 scene 328 is loaded.
# Ntire2022 scene 329 is loaded.
# Ntire2022 scene 330 is loaded.
# Ntire2022 scene 331 is loaded.
# Ntire2022 scene 332 is loaded.
# Ntire2022 scene 333 is loaded.
# Ntire2022 scene 334 is loaded.
# Ntire2022 scene 335 is loaded.
# Ntire2022 scene 336 is loaded.
# Ntire2022 scene 337 is loaded.
# Ntire2022 scene 338 is loaded.
# Ntire2022 scene 339 is loaded.
# Ntire2022 scene 340 is loaded.
# Ntire2022 scene 341 is loaded.
# Ntire2022 scene 342 is loaded.
# Ntire2022 scene 343 is loaded.
# Ntire2022 scene 344 is loaded.
# Ntire2022 scene 345 is loaded.
# Ntire2022 scene 346 is loaded.
# Ntire2022 scene 347 is loaded.
# Ntire2022 scene 348 is loaded.
# Ntire2022 scene 349 is loaded.
# Ntire2022 scene 350 is loaded.
# Ntire2022 scene 351 is loaded.
# Ntire2022 scene 352 is loaded.
# Ntire2022 scene 353 is loaded.
# Ntire2022 scene 354 is loaded.
# Ntire2022 scene 355 is loaded.
# Ntire2022 scene 356 is loaded.
# Ntire2022 scene 357 is loaded.
# Ntire2022 scene 358 is loaded.
# Ntire2022 scene 359 is loaded.
# Ntire2022 scene 360 is loaded.
# Ntire2022 scene 361 is loaded.
# Ntire2022 scene 362 is loaded.
# Ntire2022 scene 363 is loaded.
# Ntire2022 scene 364 is loaded.
# Ntire2022 scene 365 is loaded.
# Ntire2022 scene 366 is loaded.
# Ntire2022 scene 367 is loaded.
# Ntire2022 scene 368 is loaded.
# Ntire2022 scene 369 is loaded.
# Ntire2022 scene 370 is loaded.
# Ntire2022 scene 371 is loaded.
# Ntire2022 scene 372 is loaded.
# Ntire2022 scene 373 is loaded.
# Ntire2022 scene 374 is loaded.
# Ntire2022 scene 375 is loaded.
# Ntire2022 scene 376 is loaded.
# Ntire2022 scene 377 is loaded.
# Ntire2022 scene 378 is loaded.
# Ntire2022 scene 379 is loaded.
# Ntire2022 scene 380 is loaded.
# Ntire2022 scene 381 is loaded.
# Ntire2022 scene 382 is loaded.
# Ntire2022 scene 383 is loaded.
# Ntire2022 scene 384 is loaded.
# Ntire2022 scene 385 is loaded.
# Ntire2022 scene 386 is loaded.
# Ntire2022 scene 387 is loaded.
# Ntire2022 scene 388 is loaded.
# Ntire2022 scene 389 is loaded.
# Ntire2022 scene 390 is loaded.
# Ntire2022 scene 391 is loaded.
# Ntire2022 scene 392 is loaded.
# Ntire2022 scene 393 is loaded.
# Ntire2022 scene 394 is loaded.
# Ntire2022 scene 395 is loaded.
# Ntire2022 scene 396 is loaded.
# Ntire2022 scene 397 is loaded.
# Ntire2022 scene 398 is loaded.
# Ntire2022 scene 399 is loaded.
# Ntire2022 scene 400 is loaded.
# Ntire2022 scene 401 is loaded.
# Ntire2022 scene 402 is loaded.
# Ntire2022 scene 403 is loaded.
# Ntire2022 scene 404 is loaded.
# Ntire2022 scene 405 is loaded.
# Ntire2022 scene 406 is loaded.
# Ntire2022 scene 407 is loaded.
# Ntire2022 scene 408 is loaded.
# Ntire2022 scene 409 is loaded.
# Ntire2022 scene 410 is loaded.
# Ntire2022 scene 411 is loaded.
# Ntire2022 scene 412 is loaded.
# Ntire2022 scene 413 is loaded.
# Ntire2022 scene 414 is loaded.
# Ntire2022 scene 415 is loaded.
# Ntire2022 scene 416 is loaded.
# Ntire2022 scene 417 is loaded.
# Ntire2022 scene 418 is loaded.
# Ntire2022 scene 419 is loaded.
# Ntire2022 scene 420 is loaded.
# Ntire2022 scene 421 is loaded.
# Ntire2022 scene 422 is loaded.
# Ntire2022 scene 423 is loaded.
# Ntire2022 scene 424 is loaded.
# Ntire2022 scene 425 is loaded.
# Ntire2022 scene 426 is loaded.
# Ntire2022 scene 427 is loaded.
# Ntire2022 scene 428 is loaded.
# Ntire2022 scene 429 is loaded.
# Ntire2022 scene 430 is loaded.
# Ntire2022 scene 431 is loaded.
# Ntire2022 scene 432 is loaded.
# Ntire2022 scene 433 is loaded.
# Ntire2022 scene 434 is loaded.
# Ntire2022 scene 435 is loaded.
# Ntire2022 scene 436 is loaded.
# Ntire2022 scene 437 is loaded.
# Ntire2022 scene 438 is loaded.
# Ntire2022 scene 439 is loaded.
# Ntire2022 scene 440 is loaded.
# Ntire2022 scene 441 is loaded.
# Ntire2022 scene 442 is loaded.
# Ntire2022 scene 443 is loaded.
# Ntire2022 scene 444 is loaded.
# Ntire2022 scene 445 is loaded.
# Ntire2022 scene 446 is loaded.
# Ntire2022 scene 447 is loaded.
# Ntire2022 scene 448 is loaded.
# Ntire2022 scene 449 is loaded.
# Ntire2022 scene 450 is loaded.
# Ntire2022 scene 451 is loaded.
# Ntire2022 scene 452 is loaded.
# Ntire2022 scene 453 is loaded.
# Ntire2022 scene 454 is loaded.
# Ntire2022 scene 455 is loaded.
# Ntire2022 scene 456 is loaded.
# Ntire2022 scene 457 is loaded.
# Ntire2022 scene 458 is loaded.
# Ntire2022 scene 459 is loaded.
# Ntire2022 scene 460 is loaded.
# Ntire2022 scene 461 is loaded.
# Ntire2022 scene 462 is loaded.
# Ntire2022 scene 463 is loaded.
# Ntire2022 scene 464 is loaded.
# Ntire2022 scene 465 is loaded.
# Ntire2022 scene 466 is loaded.
# Ntire2022 scene 467 is loaded.
# Ntire2022 scene 468 is loaded.
# Ntire2022 scene 469 is loaded.
# Ntire2022 scene 470 is loaded.
# Ntire2022 scene 471 is loaded.
# Ntire2022 scene 472 is loaded.
# Ntire2022 scene 473 is loaded.
# Ntire2022 scene 474 is loaded.
# Ntire2022 scene 475 is loaded.
# Ntire2022 scene 476 is loaded.
# Ntire2022 scene 477 is loaded.
# Ntire2022 scene 478 is loaded.
# Ntire2022 scene 479 is loaded.
# Ntire2022 scene 480 is loaded.
# Ntire2022 scene 481 is loaded.
# Ntire2022 scene 482 is loaded.
# Ntire2022 scene 483 is loaded.
# Ntire2022 scene 484 is loaded.
# Ntire2022 scene 485 is loaded.
# Ntire2022 scene 486 is loaded.
# Ntire2022 scene 487 is loaded.
# Ntire2022 scene 488 is loaded.
# Ntire2022 scene 489 is loaded.
# Ntire2022 scene 490 is loaded.
# Ntire2022 scene 491 is loaded.
# Ntire2022 scene 492 is loaded.
# Ntire2022 scene 493 is loaded.
# Ntire2022 scene 494 is loaded.
# Ntire2022 scene 495 is loaded.
# Ntire2022 scene 496 is loaded.
# Ntire2022 scene 497 is loaded.
# Ntire2022 scene 498 is loaded.
# Ntire2022 scene 499 is loaded.
# Ntire2022 scene 500 is loaded.
# Ntire2022 scene 501 is loaded.
# Ntire2022 scene 502 is loaded.
# Ntire2022 scene 503 is loaded.
# Ntire2022 scene 504 is loaded.
# Ntire2022 scene 505 is loaded.
# Ntire2022 scene 506 is loaded.
# Ntire2022 scene 507 is loaded.
# Ntire2022 scene 508 is loaded.
# Ntire2022 scene 509 is loaded.
# Ntire2022 scene 510 is loaded.
# Ntire2022 scene 511 is loaded.
# Ntire2022 scene 512 is loaded.
# Ntire2022 scene 513 is loaded.
# Ntire2022 scene 514 is loaded.
# Ntire2022 scene 515 is loaded.
# Ntire2022 scene 516 is loaded.
# Ntire2022 scene 517 is loaded.
# Ntire2022 scene 518 is loaded.
# Ntire2022 scene 519 is loaded.
# Ntire2022 scene 520 is loaded.
# Ntire2022 scene 521 is loaded.
# Ntire2022 scene 522 is loaded.
# Ntire2022 scene 523 is loaded.
# Ntire2022 scene 524 is loaded.
# Ntire2022 scene 525 is loaded.
# Ntire2022 scene 526 is loaded.
# Ntire2022 scene 527 is loaded.
# Ntire2022 scene 528 is loaded.
# Ntire2022 scene 529 is loaded.
# Ntire2022 scene 530 is loaded.
# Ntire2022 scene 531 is loaded.
# Ntire2022 scene 532 is loaded.
# Ntire2022 scene 533 is loaded.
# Ntire2022 scene 534 is loaded.
# Ntire2022 scene 535 is loaded.
# Ntire2022 scene 536 is loaded.
# Ntire2022 scene 537 is loaded.
# Ntire2022 scene 538 is loaded.
# Ntire2022 scene 539 is loaded.
# Ntire2022 scene 540 is loaded.
# Ntire2022 scene 541 is loaded.
# Ntire2022 scene 542 is loaded.
# Ntire2022 scene 543 is loaded.
# Ntire2022 scene 544 is loaded.
# Ntire2022 scene 545 is loaded.
# Ntire2022 scene 546 is loaded.
# Ntire2022 scene 547 is loaded.
# Ntire2022 scene 548 is loaded.
# Ntire2022 scene 549 is loaded.
# Ntire2022 scene 550 is loaded.
# Ntire2022 scene 551 is loaded.
# Ntire2022 scene 552 is loaded.
# Ntire2022 scene 553 is loaded.
# Ntire2022 scene 554 is loaded.
# Ntire2022 scene 555 is loaded.
# Ntire2022 scene 556 is loaded.
# Ntire2022 scene 557 is loaded.
# Ntire2022 scene 558 is loaded.
# Ntire2022 scene 559 is loaded.
# Ntire2022 scene 560 is loaded.
# Ntire2022 scene 561 is loaded.
# Ntire2022 scene 562 is loaded.
# Ntire2022 scene 563 is loaded.
# Ntire2022 scene 564 is loaded.
# Ntire2022 scene 565 is loaded.
# Ntire2022 scene 566 is loaded.
# Ntire2022 scene 567 is loaded.
# Ntire2022 scene 568 is loaded.
# Ntire2022 scene 569 is loaded.
# Ntire2022 scene 570 is loaded.
# Ntire2022 scene 571 is loaded.
# Ntire2022 scene 572 is loaded.
# Ntire2022 scene 573 is loaded.
# Ntire2022 scene 574 is loaded.
# Ntire2022 scene 575 is loaded.
# Ntire2022 scene 576 is loaded.
# Ntire2022 scene 577 is loaded.
# Ntire2022 scene 578 is loaded.
# Ntire2022 scene 579 is loaded.
# Ntire2022 scene 580 is loaded.
# Ntire2022 scene 581 is loaded.
# Ntire2022 scene 582 is loaded.
# Ntire2022 scene 583 is loaded.
# Ntire2022 scene 584 is loaded.
# Ntire2022 scene 585 is loaded.
# Ntire2022 scene 586 is loaded.
# Ntire2022 scene 587 is loaded.
# Ntire2022 scene 588 is loaded.
# Ntire2022 scene 589 is loaded.
# Ntire2022 scene 590 is loaded.
# Ntire2022 scene 591 is loaded.
# Ntire2022 scene 592 is loaded.
# Ntire2022 scene 593 is loaded.
# Ntire2022 scene 594 is loaded.
# Ntire2022 scene 595 is loaded.
# Ntire2022 scene 596 is loaded.
# Ntire2022 scene 597 is loaded.
# Ntire2022 scene 598 is loaded.
# Ntire2022 scene 599 is loaded.
# Ntire2022 scene 600 is loaded.
# Ntire2022 scene 601 is loaded.
# Ntire2022 scene 602 is loaded.
# Ntire2022 scene 603 is loaded.
# Ntire2022 scene 604 is loaded.
# Ntire2022 scene 605 is loaded.
# Ntire2022 scene 606 is loaded.
# Ntire2022 scene 607 is loaded.
# Ntire2022 scene 608 is loaded.
# Ntire2022 scene 609 is loaded.
# Ntire2022 scene 610 is loaded.
# Ntire2022 scene 611 is loaded.
# Ntire2022 scene 612 is loaded.
# Ntire2022 scene 613 is loaded.
# Ntire2022 scene 614 is loaded.
# Ntire2022 scene 615 is loaded.
# Ntire2022 scene 616 is loaded.
# Ntire2022 scene 617 is loaded.
# Ntire2022 scene 618 is loaded.
# Ntire2022 scene 619 is loaded.
# Ntire2022 scene 620 is loaded.
# Ntire2022 scene 621 is loaded.
# Ntire2022 scene 622 is loaded.
# Ntire2022 scene 623 is loaded.
# Ntire2022 scene 624 is loaded.
# Ntire2022 scene 625 is loaded.
# Ntire2022 scene 626 is loaded.
# Ntire2022 scene 627 is loaded.
# Ntire2022 scene 628 is loaded.
# Ntire2022 scene 629 is loaded.
# Ntire2022 scene 630 is loaded.
# Ntire2022 scene 631 is loaded.
# Ntire2022 scene 632 is loaded.
# Ntire2022 scene 633 is loaded.
# Ntire2022 scene 634 is loaded.
# Ntire2022 scene 635 is loaded.
# Ntire2022 scene 636 is loaded.
# Ntire2022 scene 637 is loaded.
# Ntire2022 scene 638 is loaded.
# Ntire2022 scene 639 is loaded.
# Ntire2022 scene 640 is loaded.
# Ntire2022 scene 641 is loaded.
# Ntire2022 scene 642 is loaded.
# Ntire2022 scene 643 is loaded.
# Ntire2022 scene 644 is loaded.
# Ntire2022 scene 645 is loaded.
# Ntire2022 scene 646 is loaded.
# Ntire2022 scene 647 is loaded.
# Ntire2022 scene 648 is loaded.
# Ntire2022 scene 649 is loaded.
# Ntire2022 scene 650 is loaded.
# Ntire2022 scene 651 is loaded.
# Ntire2022 scene 652 is loaded.
# Ntire2022 scene 653 is loaded.
# Ntire2022 scene 654 is loaded.
# Ntire2022 scene 655 is loaded.
# Ntire2022 scene 656 is loaded.
# Ntire2022 scene 657 is loaded.
# Ntire2022 scene 658 is loaded.
# Ntire2022 scene 659 is loaded.
# Ntire2022 scene 660 is loaded.
# Ntire2022 scene 661 is loaded.
# Ntire2022 scene 662 is loaded.
# Ntire2022 scene 663 is loaded.
# Ntire2022 scene 664 is loaded.
# Ntire2022 scene 665 is loaded.
# Ntire2022 scene 666 is loaded.
# Ntire2022 scene 667 is loaded.
# Ntire2022 scene 668 is loaded.
# Ntire2022 scene 669 is loaded.
# Ntire2022 scene 670 is loaded.
# Ntire2022 scene 671 is loaded.
# Ntire2022 scene 672 is loaded.
# Ntire2022 scene 673 is loaded.
# Ntire2022 scene 674 is loaded.
# Ntire2022 scene 675 is loaded.
# Ntire2022 scene 676 is loaded.
# Ntire2022 scene 677 is loaded.
# Ntire2022 scene 678 is loaded.
# Ntire2022 scene 679 is loaded.
# Ntire2022 scene 680 is loaded.
# Ntire2022 scene 681 is loaded.
# Ntire2022 scene 682 is loaded.
# Ntire2022 scene 683 is loaded.
# Ntire2022 scene 684 is loaded.
# Ntire2022 scene 685 is loaded.
# Ntire2022 scene 686 is loaded.
# Ntire2022 scene 687 is loaded.
# Ntire2022 scene 688 is loaded.
# Ntire2022 scene 689 is loaded.
# Ntire2022 scene 690 is loaded.
# Ntire2022 scene 691 is loaded.
# Ntire2022 scene 692 is loaded.
# Ntire2022 scene 693 is loaded.
# Ntire2022 scene 694 is loaded.
# Ntire2022 scene 695 is loaded.
# Ntire2022 scene 696 is loaded.
# Ntire2022 scene 697 is loaded.
# Ntire2022 scene 698 is loaded.
# Ntire2022 scene 699 is loaded.
# Ntire2022 scene 700 is loaded.
# Ntire2022 scene 701 is loaded.
# Ntire2022 scene 702 is loaded.
# Ntire2022 scene 703 is loaded.
# Ntire2022 scene 704 is loaded.
# Ntire2022 scene 705 is loaded.
# Ntire2022 scene 706 is loaded.
# Ntire2022 scene 707 is loaded.
# Ntire2022 scene 708 is loaded.
# Ntire2022 scene 709 is loaded.
# Ntire2022 scene 710 is loaded.
# Ntire2022 scene 711 is loaded.
# Ntire2022 scene 712 is loaded.
# Ntire2022 scene 713 is loaded.
# Ntire2022 scene 714 is loaded.
# Ntire2022 scene 715 is loaded.
# Ntire2022 scene 716 is loaded.
# Ntire2022 scene 717 is loaded.
# Ntire2022 scene 718 is loaded.
# Ntire2022 scene 719 is loaded.
# Ntire2022 scene 720 is loaded.
# Ntire2022 scene 721 is loaded.
# Ntire2022 scene 722 is loaded.
# Ntire2022 scene 723 is loaded.
# Ntire2022 scene 724 is loaded.
# Ntire2022 scene 725 is loaded.
# Ntire2022 scene 726 is loaded.
# Ntire2022 scene 727 is loaded.
# Ntire2022 scene 728 is loaded.
# Ntire2022 scene 729 is loaded.
# Ntire2022 scene 730 is loaded.
# Ntire2022 scene 731 is loaded.
# Ntire2022 scene 732 is loaded.
# Ntire2022 scene 733 is loaded.
# Ntire2022 scene 734 is loaded.
# Ntire2022 scene 735 is loaded.
# Ntire2022 scene 736 is loaded.
# Ntire2022 scene 737 is loaded.
# Ntire2022 scene 738 is loaded.
# Ntire2022 scene 739 is loaded.
# Ntire2022 scene 740 is loaded.
# Ntire2022 scene 741 is loaded.
# Ntire2022 scene 742 is loaded.
# Ntire2022 scene 743 is loaded.
# Ntire2022 scene 744 is loaded.
# Ntire2022 scene 745 is loaded.
# Ntire2022 scene 746 is loaded.
# Ntire2022 scene 747 is loaded.
# Ntire2022 scene 748 is loaded.
# Ntire2022 scene 749 is loaded.
# Ntire2022 scene 750 is loaded.
# Ntire2022 scene 751 is loaded.
# Ntire2022 scene 752 is loaded.
# Ntire2022 scene 753 is loaded.
# Ntire2022 scene 754 is loaded.
# Ntire2022 scene 755 is loaded.
# Ntire2022 scene 756 is loaded.
# Ntire2022 scene 757 is loaded.
# Ntire2022 scene 758 is loaded.
# Ntire2022 scene 759 is loaded.
# Ntire2022 scene 760 is loaded.
# Ntire2022 scene 761 is loaded.
# Ntire2022 scene 762 is loaded.
# Ntire2022 scene 763 is loaded.
# Ntire2022 scene 764 is loaded.
# Ntire2022 scene 765 is loaded.
# Ntire2022 scene 766 is loaded.
# Ntire2022 scene 767 is loaded.
# Ntire2022 scene 768 is loaded.
# Ntire2022 scene 769 is loaded.
# Ntire2022 scene 770 is loaded.
# Ntire2022 scene 771 is loaded.
# Ntire2022 scene 772 is loaded.
# Ntire2022 scene 773 is loaded.
# Ntire2022 scene 774 is loaded.
# Ntire2022 scene 775 is loaded.
# Ntire2022 scene 776 is loaded.
# Ntire2022 scene 777 is loaded.
# Ntire2022 scene 778 is loaded.
# Ntire2022 scene 779 is loaded.
# Ntire2022 scene 780 is loaded.
# Ntire2022 scene 781 is loaded.
# Ntire2022 scene 782 is loaded.
# Ntire2022 scene 783 is loaded.
# Ntire2022 scene 784 is loaded.
# Ntire2022 scene 785 is loaded.
# Ntire2022 scene 786 is loaded.
# Ntire2022 scene 787 is loaded.
# Ntire2022 scene 788 is loaded.
# Ntire2022 scene 789 is loaded.
# Ntire2022 scene 790 is loaded.
# Ntire2022 scene 791 is loaded.
# Ntire2022 scene 792 is loaded.
# Ntire2022 scene 793 is loaded.
# Ntire2022 scene 794 is loaded.
# Ntire2022 scene 795 is loaded.
# Ntire2022 scene 796 is loaded.
# len(hyper_valid) of ntire2022 dataset:150
# len(bgr_valid) of ntire2022 dataset:150
# Ntire2022 scene 0 is loaded.
# Ntire2022 scene 1 is loaded.
# Ntire2022 scene 2 is loaded.
# Ntire2022 scene 3 is loaded.
# Ntire2022 scene 4 is loaded.
# Ntire2022 scene 5 is loaded.
# Ntire2022 scene 6 is loaded.
# Ntire2022 scene 7 is loaded.
# Ntire2022 scene 8 is loaded.
# Ntire2022 scene 9 is loaded.
# Ntire2022 scene 10 is loaded.
# Ntire2022 scene 11 is loaded.
# Ntire2022 scene 12 is loaded.
# Ntire2022 scene 13 is loaded.
# Ntire2022 scene 14 is loaded.
# Ntire2022 scene 15 is loaded.
# Ntire2022 scene 16 is loaded.
# Ntire2022 scene 17 is loaded.
# Ntire2022 scene 18 is loaded.
# Ntire2022 scene 19 is loaded.
# Ntire2022 scene 20 is loaded.
# Ntire2022 scene 21 is loaded.
# Ntire2022 scene 22 is loaded.
# Ntire2022 scene 23 is loaded.
# Ntire2022 scene 24 is loaded.
# Ntire2022 scene 25 is loaded.
# Ntire2022 scene 26 is loaded.
# Ntire2022 scene 27 is loaded.
# Ntire2022 scene 28 is loaded.
# Ntire2022 scene 29 is loaded.
# Ntire2022 scene 30 is loaded.
# Ntire2022 scene 31 is loaded.
# Ntire2022 scene 32 is loaded.
# Ntire2022 scene 33 is loaded.
# Ntire2022 scene 34 is loaded.
# Ntire2022 scene 35 is loaded.
# Ntire2022 scene 36 is loaded.
# Ntire2022 scene 37 is loaded.
# Ntire2022 scene 38 is loaded.
# Ntire2022 scene 39 is loaded.
# Ntire2022 scene 40 is loaded.
# Ntire2022 scene 41 is loaded.
# Ntire2022 scene 42 is loaded.
# Ntire2022 scene 43 is loaded.
# Ntire2022 scene 44 is loaded.
# Ntire2022 scene 45 is loaded.
# Ntire2022 scene 46 is loaded.
# Ntire2022 scene 47 is loaded.
# Ntire2022 scene 48 is loaded.
# Ntire2022 scene 49 is loaded.
# Ntire2022 scene 50 is loaded.
# Ntire2022 scene 51 is loaded.
# Ntire2022 scene 52 is loaded.
# Ntire2022 scene 53 is loaded.
# Ntire2022 scene 54 is loaded.
# Ntire2022 scene 55 is loaded.
# Ntire2022 scene 56 is loaded.
# Ntire2022 scene 57 is loaded.
# Ntire2022 scene 58 is loaded.
# Ntire2022 scene 59 is loaded.
# Ntire2022 scene 60 is loaded.
# Ntire2022 scene 61 is loaded.
# Ntire2022 scene 62 is loaded.
# Ntire2022 scene 63 is loaded.
# Ntire2022 scene 64 is loaded.
# Ntire2022 scene 65 is loaded.
# Ntire2022 scene 66 is loaded.
# Ntire2022 scene 67 is loaded.
# Ntire2022 scene 68 is loaded.
# Ntire2022 scene 69 is loaded.
# Ntire2022 scene 70 is loaded.
# Ntire2022 scene 71 is loaded.
# Ntire2022 scene 72 is loaded.
# Ntire2022 scene 73 is loaded.
# Ntire2022 scene 74 is loaded.
# Ntire2022 scene 75 is loaded.
# Ntire2022 scene 76 is loaded.
# Ntire2022 scene 77 is loaded.
# Ntire2022 scene 78 is loaded.
# Ntire2022 scene 79 is loaded.
# Ntire2022 scene 80 is loaded.
# Ntire2022 scene 81 is loaded.
# Ntire2022 scene 82 is loaded.
# Ntire2022 scene 83 is loaded.
# Ntire2022 scene 84 is loaded.
# Ntire2022 scene 85 is loaded.
# Ntire2022 scene 86 is loaded.
# Ntire2022 scene 87 is loaded.
# Ntire2022 scene 88 is loaded.
# Ntire2022 scene 89 is loaded.
# Ntire2022 scene 90 is loaded.
# Ntire2022 scene 91 is loaded.
# Ntire2022 scene 92 is loaded.
# Ntire2022 scene 93 is loaded.
# Ntire2022 scene 94 is loaded.
# Ntire2022 scene 95 is loaded.
# Ntire2022 scene 96 is loaded.
# Ntire2022 scene 97 is loaded.
# Ntire2022 scene 98 is loaded.
# Ntire2022 scene 99 is loaded.
# Ntire2022 scene 100 is loaded.
# Ntire2022 scene 101 is loaded.
# Ntire2022 scene 102 is loaded.
# Ntire2022 scene 103 is loaded.
# Ntire2022 scene 104 is loaded.
# Ntire2022 scene 105 is loaded.
# Ntire2022 scene 106 is loaded.
# Ntire2022 scene 107 is loaded.
# Ntire2022 scene 108 is loaded.
# Ntire2022 scene 109 is loaded.
# Ntire2022 scene 110 is loaded.
# Ntire2022 scene 111 is loaded.
# Ntire2022 scene 112 is loaded.
# Ntire2022 scene 113 is loaded.
# Ntire2022 scene 114 is loaded.
# Ntire2022 scene 115 is loaded.
# Ntire2022 scene 116 is loaded.
# Ntire2022 scene 117 is loaded.
# Ntire2022 scene 118 is loaded.
# Ntire2022 scene 119 is loaded.
# Ntire2022 scene 120 is loaded.
# Ntire2022 scene 121 is loaded.
# Ntire2022 scene 122 is loaded.
# Ntire2022 scene 123 is loaded.
# Ntire2022 scene 124 is loaded.
# Ntire2022 scene 125 is loaded.
# Ntire2022 scene 126 is loaded.
# Ntire2022 scene 127 is loaded.
# Ntire2022 scene 128 is loaded.
# Ntire2022 scene 129 is loaded.
# Ntire2022 scene 130 is loaded.
# Ntire2022 scene 131 is loaded.
# Ntire2022 scene 132 is loaded.
# Ntire2022 scene 133 is loaded.
# Ntire2022 scene 134 is loaded.
# Ntire2022 scene 135 is loaded.
# Ntire2022 scene 136 is loaded.
# Ntire2022 scene 137 is loaded.
# Ntire2022 scene 138 is loaded.
# Ntire2022 scene 139 is loaded.
# Ntire2022 scene 140 is loaded.
# Ntire2022 scene 141 is loaded.
# Ntire2022 scene 142 is loaded.
# Ntire2022 scene 143 is loaded.
# Ntire2022 scene 144 is loaded.
# Ntire2022 scene 145 is loaded.
# Ntire2022 scene 146 is loaded.
# Ntire2022 scene 147 is loaded.
# Ntire2022 scene 148 is loaded.
# Ntire2022 scene 149 is loaded.
# Train Images Shape: torch.Size([1, 3, 512, 512])
# Train Labels Shape: torch.Size([1, 31, 512, 512])
# Valid Images Shape: torch.Size([1, 3, 512, 512])
# Valid Labels Shape: torch.Size([1, 31, 512, 512])

# %%
x, y = next(iter(train_loader))
x.shape, y.shape
# Out:
# (torch.Size([1, 3, 512, 512]), torch.Size([1, 31, 512, 512]))

# %%
x, y = next(iter(valid_loader))
x.shape, y.shape
# Out:
# (torch.Size([1, 3, 512, 512]), torch.Size([1, 31, 512, 512]))

# %% [markdown]
# ## Visualize the data

# %%
import matplotlib.pyplot as plt

sample = train_dataset[0]
x, y = sample[0], sample[1]

# Create subplots for the 3-channel input (RGB)
plt.figure(figsize=(12, 4))
for i in range(x.shape[0]):  # Loop through channels
    plt.subplot(1, 3, i + 1)  # Adjust for the number of input channels (3)
    channel_data = x[i]
    plt.imshow(channel_data, cmap='gray')  # Display each channel in grayscale
    plt.title(f'Input Channel {i + 1}')
    plt.axis('off')

# Create subplots for the 31-channel output (Hyperspectral)
plt.figure(figsize=(18, 18))  # Adjust size as needed
for i in range(y.shape[0]):  # Loop through channels
    plt.subplot(6, 6, i + 1)  # Adjust subplot grid for 31 channels
    channel_data = y[i]
    plt.imshow(channel_data, cmap='gray')  # Display each channel in grayscale
    plt.title(f'Output Channel {i + 1}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## custom SAM LOSS

# %%
import torch
import torch.nn as nn

class SAMLoss(nn.Module):
    def __init__(self):
        super(SAMLoss, self).__init__()

    def forward(self, predicted_hsi, ground_truth_hsi):
        # Ensure the input tensors have the same shape
        assert predicted_hsi.shape == ground_truth_hsi.shape, "Input tensor shapes must match."

        # Reshape tensors if necessary
        if predicted_hsi.dim() == 4:  # If the tensors are 4D, flatten them
            predicted_hsi = predicted_hsi.view(predicted_hsi.size(0), -1)
            ground_truth_hsi = ground_truth_hsi.view(ground_truth_hsi.size(0), -1)

        # Calculate the dot product and magnitudes
        dot_product = torch.sum(predicted_hsi * ground_truth_hsi, dim=1)
        magnitude_pred = torch.norm(predicted_hsi, dim=1)
        magnitude_gt = torch.norm(ground_truth_hsi, dim=1)

        # Calculate the cosine of the spectral angle
        cosine_theta = dot_product / (magnitude_pred * magnitude_gt)

        # Calculate the spectral angle in radians
        spectral_angle = torch.acos(cosine_theta)

        # Return the mean spectral angle as the loss
        return torch.mean(spectral_angle)
    
# class Loss_MRAE(nn.Module):
#     def __init__(self):
#         super(Loss_MRAE, self).__init__()

#     def forward(self, outputs, label):
#         assert outputs.shape == label.shape
#         error = torch.abs(outputs - label) / label
#         mrae = torch.mean(error.view(-1))
#         return mrae

class Loss_RMSE(nn.Module):
    def __init__(self):
        super(Loss_RMSE, self).__init__()

    def forward(self, outputs, label):
        assert outputs.shape == label.shape
        error = outputs-label
        sqrt_error = torch.pow(error,2)
        rmse = torch.sqrt(torch.mean(sqrt_error.view(-1)))
        return rmse

class Loss_PSNR(nn.Module):
    def __init__(self):
        super(Loss_PSNR, self).__init__()

    def forward(self, im_true, im_fake, data_range=255):
        N = im_true.size()[0]
        C = im_true.size()[1]
        H = im_true.size()[2]
        W = im_true.size()[3]
        Itrue = im_true.clamp(0., 1.).mul_(data_range).resize_(N, C * H * W)
        Ifake = im_fake.clamp(0., 1.).mul_(data_range).resize_(N, C * H * W)
        mse = nn.MSELoss(reduce=False)
        err = mse(Itrue, Ifake).sum(dim=1, keepdim=True).div_(C * H * W)
        psnr = 10. * torch.log((data_range ** 2) / err) / np.log(10.)
        return torch.mean(psnr)

import tensorflow as tf

class MRAELoss(torch.nn.Module):
    def __init__(self, epsilon=1e-8):
    
        super(MRAELoss, self).__init__()
        self.epsilon = epsilon

    def forward(self, pred, target):
    
        # Ensure that the target and predictions are positive
        pred = torch.clamp(pred, min=self.epsilon)
        target = torch.clamp(target, min=self.epsilon)

        # Compute the relative absolute error
        relative_error = torch.abs((pred - target) / target)

        # Compute the mean of the relative errors
        mrae = torch.mean(relative_error)

        return mrae

# %% [markdown]
# ## combined loss L1loss and SAM

# %%
import torch.nn as nn

class CombinedLoss(nn.Module):
    def __init__(self, alpha=0.5, beta=0.5):
        super(CombinedLoss, self).__init__()
        self.alpha = alpha
        self.beta = beta
        self.l1_loss = nn.L1Loss()
        self.sam_loss = SAMLoss()

    def forward(self, outputs, labels):
        loss_l1 = self.l1_loss(outputs, labels)
        loss_sam = self.sam_loss(outputs, labels)
        combined_loss = self.alpha * loss_l1 + self.beta * loss_sam
        return combined_loss

class MseL1Loss(nn.Module):
    def __init__(self, alpha=0.5, beta=0.5):
        super(MseL1Loss, self).__init__()
        self.alpha = alpha
        self.beta = beta
        self.mse_loss = nn.MSELoss()
        self.l1_loss = nn.L1Loss()

    def forward(self, outputs, labels):
        loss_mse = self.mse_loss(outputs, labels)
        loss_l1 = self.l1_loss(outputs, labels)
        combined_loss = self.alpha * loss_mse + self.beta * loss_l1
        return combined_loss
    
    
class SRLoss(nn.Module):
    def __init__(self, alpha=0.5, beta=0.5):
        super(SRLoss, self).__init__()
        self.alpha = alpha  # Weight for SAM loss
        self.beta = beta    # Weight for RMSE loss

        # Define the SAM and RMSE loss functions
        self.sam_loss = SAMLoss()
        self.rmse_loss = Loss_RMSE()

    def forward(self, outputs, labels):
        # Calculate the SAM loss
        sam_loss = self.sam_loss(outputs, labels)

        # Calculate the RMSE loss
        rmse_loss = self.rmse_loss(outputs, labels)

        # Combine the SAM and RMSE losses using weights (alpha and beta)
        combined_loss = self.alpha * sam_loss + self.beta * rmse_loss

        return combined_loss

    
class MSLoss(nn.Module):
    def __init__(self, alpha=0.5, beta=0.5, epsilon=1e-8):
        """
        Initialize the combined loss function.

        :param alpha: Weight for the MRAE loss component.
        :param beta: Weight for the SAM loss component.
        :param epsilon: Small value to ensure numerical stability in MRAE.
        """
        super(MSLoss, self).__init__()
        self.alpha = alpha
        self.beta = beta
        self.epsilon = epsilon
        self.mrae_loss = MRAELoss(epsilon)
        self.sam_loss = SAMLoss()

    def forward(self, predicted_hsi, ground_truth_hsi):
        """
        Forward pass to compute the combined loss.

        :param predicted_hsi: Predicted hyperspectral image.
        :param ground_truth_hsi: Ground truth hyperspectral image.
        :return: Combined loss value.
        """
        # Compute individual losses
        loss_mrae = self.mrae_loss(predicted_hsi, ground_truth_hsi)
        loss_sam = self.sam_loss(predicted_hsi, ground_truth_hsi)

        # Combine the losses
        combined_loss = self.alpha * loss_mrae + self.beta * loss_sam
        return combined_loss

# %% [markdown]
# ## HyperAttention model with spacial, spectral attention and fft block

# %%
import torch.nn.functional as F
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader
from tqdm import tqdm



device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class SpectralAttention(nn.Module):
    def __init__(self, in_channels):
        super(SpectralAttention, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, 1, kernel_size=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_pool = F.avg_pool2d(x, (x.size(2), x.size(3)))
        channel_weights = self.sigmoid(self.conv1(avg_pool))
        x_att = x * channel_weights
        return x_att


class SpatialAttention(nn.Module):
    def __init__(self, in_channels):
        super(SpatialAttention, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, 1, kernel_size=1)
        self.sigmoid = nn.Sigmoid()
        self.batch_norm = nn.BatchNorm2d(in_channels)  # Batch Normalization

    def forward(self, x):
        x = self.batch_norm(x)  # Apply Batch Normalization
        spatial_weights = self.sigmoid(self.conv1(x))
        x_att = x * spatial_weights
        return x_att

class FFTInteraction(nn.Module):
    def __init__(self):
        super(FFTInteraction, self).__init__()

    def forward(self, x):
        fft_x = torch.fft.fft2(x)
        amplitude = torch.abs(fft_x)
        phase = torch.angle(fft_x)
        return amplitude, phase
    
class IFFTInteraction(nn.Module):
    def __init__(self):
        super(IFFTInteraction, self).__init__()

    def forward(self, amplitude, phase):
        # Combine amplitude and phase to get complex representation
        complex_representation = amplitude * torch.exp(1j * phase)

        # Perform inverse FFT
        ifft_result = torch.fft.ifft2(complex_representation)

        # Take the real part
        ifft_real = ifft_result.real

        return ifft_real

class OutputNormalization(nn.Module):
    def forward(self, x):
        min_val = torch.min(x)
        range_val = torch.max(x) - min_val
        return (x - min_val) / (range_val + 1e-8)

class FocusNet(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(FocusNet, self).__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        # Attention block after the encoder
        self.spectral_attention_encoder = SpectralAttention(64)

        # Residual Blocks
        self.residual_blocks = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.spatial_attention_res = SpatialAttention(128)
        

        # Additional Residual Blocks for increased complexity
        self.additional_residual_blocks = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        # Additional Residual Blocks for increased complexity
        self.new_residual_blocks = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
        )
        
        self.bottleneck = nn.Sequential(
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
        )
        
         # Decoder
        self.dec1 = nn.Sequential(
            nn.ConvTranspose2d(128, 128, kernel_size=2, stride=2),  # Increase stride to upsample
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
        )
        
        self.spatial_attention_dec1 = SpatialAttention(64)
        
        self.output_norm = OutputNormalization()
        
        self.dec2 = nn.Sequential(
            nn.ConvTranspose2d(64, 64, kernel_size=2, stride=2),  # Increase stride to upsample
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(64, out_channels, kernel_size=2, stride=2) ,
            nn.ReLU(inplace=True),
        )


    def forward(self, x):
        # Encoder
        enc1 = self.encoder(x)
        
        enc1 = self.spectral_attention_encoder(enc1)

        # Residual Blocks
        res_blocks = self.residual_blocks(enc1)

        # Additional Residual Blocks
        additional_res_blocks = self.additional_residual_blocks(res_blocks)
        
        new_res_blocks = self.new_residual_blocks(additional_res_blocks)

        # Adjust the spatial dimensions of enc1 for addition
        enc1_adjusted = torch.nn.functional.interpolate(enc1, size=new_res_blocks.size()[2:], mode='bilinear', align_corners=False)

        # Adjust the number of channels to match additional_res_blocks
        enc1_adjusted = self.adjust_channels(enc1_adjusted, new_res_blocks.size(1))
        
        # Element-wise addition
        combined_features = new_res_blocks + enc1_adjusted
        
#         combined_features = self.spectral_attention_bot(combined_features)

        # Decoder
        bot1 = self.bottleneck(combined_features)
        
        
        dec1_o = self.dec1(bot1)
        
         # Adjust the spatial dimensions of enc1 for addition
        res_adjusted = torch.nn.functional.interpolate(res_blocks, size=dec1_o.size()[2:], mode='bilinear', align_corners=False)

        # Adjust the number of channels to match additional_res_blocks
        res_adjusted = self.adjust_channels(res_adjusted, dec1_o.size(1))
        res_adjusted_att = self.spatial_attention_dec1(res_adjusted)
        
        concat = dec1_o + res_adjusted_att
        
        dec2_o  = self.dec2(dec1_o)
#         dec2_o = self.dec2(concat)
        
        dec2_o = self.output_norm(dec2_o)
                                  
        return dec2_o

    def adjust_channels(self, x, target_channels):
        if x.size(1) == target_channels:
            return x
        else:
            # Move the convolutional layer to the same device as the input tensor
            conv_layer = nn.Conv2d(x.size(1), target_channels, kernel_size=1).to(x.device)
            return conv_layer(x)

# %% [markdown]
# ## training

# %%
import torch
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm import tqdm
import matplotlib.pyplot as plt
from IPython.display import clear_output

# Model, criterion, and other components initialization code remains the same

# Lists to store losses for plotting
train_losses = []
val_losses = []
verbose_logs = []

# Set hyperparameters
batch_size = 1
learning_rate = 0.001  # Define the learning rate before the optimizer
num_epochs = 2000  # Number of epochs
checkpoint_interval = 200

# Initialize the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = FocusNet(in_channels=3, out_channels=31).to(device).float()

# Initialize optimizer with beta parameters
beta1 = 0.9
beta2 = 0.999
optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=(beta1, beta2))

# Define and initialize the cosine annealing scheduler
T_max = 60  # The number of epochs for cosine annealing
scheduler = CosineAnnealingLR(optimizer, T_max)
# criterion = SAMLoss()
# criterion = SRLoss()
criterion = MSLoss()

# Training and validation functions remain the same

best_val_loss = float('inf')
best_model_epoch = 0

def train_one_epoch(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    for inputs, labels in tqdm(train_loader):
        inputs, labels = inputs.to(device), labels.to(device)

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    return running_loss / len(train_loader)

# Function to validate the model
from piq import ssim, psnr

def validate_model(model, valid_loader, criterion, device):
    model.eval()
    running_loss = 0.0
    running_ssim = 0.0
    running_psnr = 0.0

    with torch.no_grad():
        for inputs, labels in tqdm(valid_loader):
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()

            # Normalize outputs and labels to [0, 1] for SSIM and PSNR calculations
            outputs = torch.clamp(outputs, 0, 1)
            labels = torch.clamp(labels, 0, 1)

            # Calculate SSIM and PSNR for each batch
            batch_ssim = ssim(outputs, labels, data_range=1.0).item()
            batch_psnr = psnr(outputs, labels, data_range=1.0).item()
            running_ssim += batch_ssim
            running_psnr += batch_psnr

        avg_loss = running_loss / len(valid_loader)
        avg_ssim = running_ssim / len(valid_loader)
        avg_psnr = running_psnr / len(valid_loader)
        
    return avg_loss, avg_ssim, avg_psnr

# Main training loop with plotting
for epoch in range(num_epochs):
    train_loss = train_one_epoch(model, train_loader, criterion, optimizer, device)
    valid_loss, valid_ssim, valid_psnr = validate_model(model, valid_loader, criterion, device)

    train_losses.append(train_loss)
    val_losses.append(valid_loss)

    # Displaying the metrics
    epoch_log = f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Valid Loss: {valid_loss:.4f}, Valid SSIM: {valid_ssim:.4f}, Valid PSNR: {valid_psnr:.4f}'

    # Step the scheduler
    scheduler.step()

    # Check and save the best model
    if valid_loss < best_val_loss:
        best_val_loss = valid_loss
        best_model_path = f'../Models/best_FocusNet_norm.pth'
        torch.save(model.state_dict(), best_model_path)
        epoch_log += f", Best model saved with validation loss: {best_val_loss:.4f} at {best_model_path}"
        print(f"Best model saved with validation loss: {best_val_loss:.4f}.......")
        best_model_epoch = epoch  # Update the best model epoch


    # Save checkpoint at specific intervals
    if (epoch + 1) % checkpoint_interval == 0:
        checkpoint_filename = f'../Models/checkpoints/FocusNet_norm_epoch_{epoch+1}.pth'
        torch.save(model.state_dict(), checkpoint_filename)
        print(f"Checkpoint saved at epoch {epoch+1}")
        
    # Update verbose logs
    verbose_logs.append(epoch_log)

    # Live plot
    clear_output(wait=True)
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')

    # Add a marker for the best model
    if best_model_epoch > 0:
        plt.scatter(best_model_epoch, val_losses[best_model_epoch], color='red', label='Best Model')

    plt.title(f'Epoch [{epoch+1}/{num_epochs}]')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    # Print all verbose logs
    for log in verbose_logs:
        print(log)

# Save the final model
final_model_filename = '../Models/final_FocusNet_norm.pth'
torch.save(model.state_dict(), final_model_filename)
print("Final model saved & training complete!")
# Out:
# Epoch [1/2000], Train Loss: 0.6513, Valid Loss: 0.5579, Valid SSIM: 0.5300, Valid PSNR: 19.4310, Best model saved with validation loss: 0.5579 at ../Models/best_FocusNet_norm.pth
# Epoch [2/2000], Train Loss: 0.5668, Valid Loss: 0.5617, Valid SSIM: 0.5069, Valid PSNR: 19.1614
# Epoch [3/2000], Train Loss: 0.5528, Valid Loss: 0.5104, Valid SSIM: 0.6526, Valid PSNR: 20.5911, Best model saved with validation loss: 0.5104 at ../Models/best_FocusNet_norm.pth
# Epoch [4/2000], Train Loss: 0.5426, Valid Loss: 0.5477, Valid SSIM: 0.5164, Valid PSNR: 19.3881
# Epoch [5/2000], Train Loss: 0.5265, Valid Loss: 0.5204, Valid SSIM: 0.5641, Valid PSNR: 19.6657
# Epoch [6/2000], Train Loss: 0.5153, Valid Loss: 0.4750, Valid SSIM: 0.6666, Valid PSNR: 20.8789, Best model saved with validation loss: 0.4750 at ../Models/best_FocusNet_norm.pth
# Epoch [7/2000], Train Loss: 0.5071, Valid Loss: 0.4637, Valid SSIM: 0.7047, Valid PSNR: 21.5785, Best model saved with validation loss: 0.4637 at ../Models/best_FocusNet_norm.pth
# Epoch [8/2000], Train Loss: 0.4907, Valid Loss: 0.4423, Valid SSIM: 0.6864, Valid PSNR: 21.3534, Best model saved with validation loss: 0.4423 at ../Models/best_FocusNet_norm.pth
# Epoch [9/2000], Train Loss: 0.4792, Valid Loss: 0.4516, Valid SSIM: 0.7063, Valid PSNR: 21.9295
# Epoch [10/2000], Train Loss: 0.4735, Valid Loss: 0.4394, Valid SSIM: 0.6770, Valid PSNR: 21.4365, Best model saved with validation loss: 0.4394 at ../Models/best_FocusNet_norm.pth
# Epoch [11/2000], Train Loss: 0.4638, Valid Loss: 0.4292, Valid SSIM: 0.6800, Valid PSNR: 21.5652, Best model saved with validation loss: 0.4292 at ../Models/best_FocusNet_norm.pth
# Epoch [12/2000], Train Loss: 0.4579, Valid Loss: 0.4607, Valid SSIM: 0.6130, Valid PSNR: 20.5970
# Epoch [13/2000], Train Loss: 0.4553, Valid Loss: 0.4390, Valid SSIM: 0.6421, Valid PSNR: 21.0840
# Epoch [14/2000], Train Loss: 0.4460, Valid Loss: 0.4588, Valid SSIM: 0.6088, Valid PSNR: 20.5288
# Epoch [15/2000], Train Loss: 0.4426, Valid Loss: 0.4125, Valid SSIM: 0.7071, Valid PSNR: 21.8825, Best model saved with validation loss: 0.4125 at ../Models/best_FocusNet_norm.pth
# Epoch [16/2000], Train Loss: 0.4476, Valid Loss: 0.4215, Valid SSIM: 0.6830, Valid PSNR: 21.4988
# Epoch [17/2000], Train Loss: 0.4356, Valid Loss: 0.4732, Valid SSIM: 0.5813, Valid PSNR: 20.3256
# Epoch [18/2000], Train Loss: 0.4264, Valid Loss: 0.4223, Valid SSIM: 0.6454, Valid PSNR: 21.1596
# Epoch [19/2000], Train Loss: 0.4103, Valid Loss: 0.4487, Valid SSIM: 0.6083, Valid PSNR: 20.3640
# Epoch [20/2000], Train Loss: 0.4105, Valid Loss: 0.3879, Valid SSIM: 0.7134, Valid PSNR: 22.3588, Best model saved with validation loss: 0.3879 at ../Models/best_FocusNet_norm.pth
# Epoch [21/2000], Train Loss: 0.4096, Valid Loss: 0.4014, Valid SSIM: 0.7250, Valid PSNR: 22.3803
# Epoch [22/2000], Train Loss: 0.4043, Valid Loss: 0.3951, Valid SSIM: 0.7387, Valid PSNR: 22.7585
# Epoch [23/2000], Train Loss: 0.3974, Valid Loss: 0.3961, Valid SSIM: 0.7367, Valid PSNR: 22.7613
# Epoch [24/2000], Train Loss: 0.4008, Valid Loss: 0.3955, Valid SSIM: 0.7065, Valid PSNR: 22.2979
# Epoch [25/2000], Train Loss: 0.3931, Valid Loss: 0.3889, Valid SSIM: 0.7254, Valid PSNR: 22.5504
# Epoch [26/2000], Train Loss: 0.3890, Valid Loss: 0.3901, Valid SSIM: 0.7380, Valid PSNR: 22.6821
# Epoch [27/2000], Train Loss: 0.3839, Valid Loss: 0.4047, Valid SSIM: 0.7463, Valid PSNR: 22.7870
# Epoch [28/2000], Train Loss: 0.3792, Valid Loss: 0.3946, Valid SSIM: 0.7162, Valid PSNR: 22.2843
# Epoch [29/2000], Train Loss: 0.3782, Valid Loss: 0.3871, Valid SSIM: 0.7277, Valid PSNR: 22.7188, Best model saved with validation loss: 0.3871 at ../Models/best_FocusNet_norm.pth
# Epoch [30/2000], Train Loss: 0.3708, Valid Loss: 0.3817, Valid SSIM: 0.7393, Valid PSNR: 22.7707, Best model saved with validation loss: 0.3817 at ../Models/best_FocusNet_norm.pth
# Epoch [31/2000], Train Loss: 0.3678, Valid Loss: 0.3828, Valid SSIM: 0.7210, Valid PSNR: 22.4044
# Epoch [32/2000], Train Loss: 0.3529, Valid Loss: 0.3674, Valid SSIM: 0.7425, Valid PSNR: 23.0884, Best model saved with validation loss: 0.3674 at ../Models/best_FocusNet_norm.pth
# Epoch [33/2000], Train Loss: 0.3390, Valid Loss: 0.3515, Valid SSIM: 0.7503, Valid PSNR: 23.3671, Best model saved with validation loss: 0.3515 at ../Models/best_FocusNet_norm.pth
# Epoch [34/2000], Train Loss: 0.3258, Valid Loss: 0.3497, Valid SSIM: 0.7521, Valid PSNR: 23.5267, Best model saved with validation loss: 0.3497 at ../Models/best_FocusNet_norm.pth
# Epoch [35/2000], Train Loss: 0.3169, Valid Loss: 0.3548, Valid SSIM: 0.7752, Valid PSNR: 23.9222
# Epoch [36/2000], Train Loss: 0.3075, Valid Loss: 0.3410, Valid SSIM: 0.7625, Valid PSNR: 23.8192, Best model saved with validation loss: 0.3410 at ../Models/best_FocusNet_norm.pth
# Epoch [37/2000], Train Loss: 0.2975, Valid Loss: 0.3387, Valid SSIM: 0.7655, Valid PSNR: 23.9543, Best model saved with validation loss: 0.3387 at ../Models/best_FocusNet_norm.pth
# Epoch [38/2000], Train Loss: 0.2913, Valid Loss: 0.3515, Valid SSIM: 0.7710, Valid PSNR: 23.9871
# Epoch [39/2000], Train Loss: 0.2877, Valid Loss: 0.3440, Valid SSIM: 0.7591, Valid PSNR: 23.8082
# Epoch [40/2000], Train Loss: 0.2822, Valid Loss: 0.3535, Valid SSIM: 0.7625, Valid PSNR: 23.6946
# Epoch [41/2000], Train Loss: 0.2766, Valid Loss: 0.3436, Valid SSIM: 0.7746, Valid PSNR: 24.0888
# Epoch [42/2000], Train Loss: 0.2734, Valid Loss: 0.3572, Valid SSIM: 0.7807, Valid PSNR: 24.2867
# Epoch [43/2000], Train Loss: 0.2699, Valid Loss: 0.3427, Valid SSIM: 0.7721, Valid PSNR: 24.1615
# Epoch [44/2000], Train Loss: 0.2663, Valid Loss: 0.3431, Valid SSIM: 0.7753, Valid PSNR: 24.1058
# Epoch [45/2000], Train Loss: 0.2636, Valid Loss: 0.3358, Valid SSIM: 0.7719, Valid PSNR: 24.1590, Best model saved with validation loss: 0.3358 at ../Models/best_FocusNet_norm.pth
# Epoch [46/2000], Train Loss: 0.2598, Valid Loss: 0.3363, Valid SSIM: 0.7789, Valid PSNR: 24.3842
# Epoch [47/2000], Train Loss: 0.2571, Valid Loss: 0.3454, Valid SSIM: 0.7768, Valid PSNR: 24.2018
# Epoch [48/2000], Train Loss: 0.2557, Valid Loss: 0.3462, Valid SSIM: 0.7872, Valid PSNR: 24.4973
# Epoch [49/2000], Train Loss: 0.2528, Valid Loss: 0.3424, Valid SSIM: 0.7865, Valid PSNR: 24.4535
# Epoch [50/2000], Train Loss: 0.2512, Valid Loss: 0.3359, Valid SSIM: 0.7801, Valid PSNR: 24.2859
# Epoch [51/2000], Train Loss: 0.2494, Valid Loss: 0.3431, Valid SSIM: 0.7832, Valid PSNR: 24.4021
# Epoch [52/2000], Train Loss: 0.2481, Valid Loss: 0.3373, Valid SSIM: 0.7853, Valid PSNR: 24.4411
# Epoch [53/2000], Train Loss: 0.2465, Valid Loss: 0.3430, Valid SSIM: 0.7893, Valid PSNR: 24.5282
# Epoch [54/2000], Train Loss: 0.2456, Valid Loss: 0.3402, Valid SSIM: 0.7884, Valid PSNR: 24.5147
# Epoch [55/2000], Train Loss: 0.2448, Valid Loss: 0.3378, Valid SSIM: 0.7868, Valid PSNR: 24.5056
# Epoch [56/2000], Train Loss: 0.2440, Valid Loss: 0.3391, Valid SSIM: 0.7874, Valid PSNR: 24.4999
# Epoch [57/2000], Train Loss: 0.2436, Valid Loss: 0.3387, Valid SSIM: 0.7875, Valid PSNR: 24.5093
# Epoch [58/2000], Train Loss: 0.2432, Valid Loss: 0.3377, Valid SSIM: 0.7879, Valid PSNR: 24.5259
# Epoch [59/2000], Train Loss: 0.2429, Valid Loss: 0.3381, Valid SSIM: 0.7879, Valid PSNR: 24.5238
# Epoch [60/2000], Train Loss: 0.2428, Valid Loss: 0.3381, Valid SSIM: 0.7878, Valid PSNR: 24.5216
# Epoch [61/2000], Train Loss: 0.2428, Valid Loss: 0.3381, Valid SSIM: 0.7878, Valid PSNR: 24.5216
# Epoch [62/2000], Train Loss: 0.2428, Valid Loss: 0.3383, Valid SSIM: 0.7880, Valid PSNR: 24.5244
# Epoch [63/2000], Train Loss: 0.2428, Valid Loss: 0.3373, Valid SSIM: 0.7872, Valid PSNR: 24.5094
# Epoch [64/2000], Train Loss: 0.2430, Valid Loss: 0.3384, Valid SSIM: 0.7883, Valid PSNR: 24.5333
# Epoch [65/2000], Train Loss: 0.2430, Valid Loss: 0.3366, Valid SSIM: 0.7864, Valid PSNR: 24.4998
# Epoch [66/2000], Train Loss: 0.2431, Valid Loss: 0.3366, Valid SSIM: 0.7877, Valid PSNR: 24.5154
# Epoch [67/2000], Train Loss: 0.2432, Valid Loss: 0.3378, Valid SSIM: 0.7867, Valid PSNR: 24.4815
# Epoch [68/2000], Train Loss: 0.2432, Valid Loss: 0.3382, Valid SSIM: 0.7864, Valid PSNR: 24.4791
# Epoch [69/2000], Train Loss: 0.2434, Valid Loss: 0.3357, Valid SSIM: 0.7874, Valid PSNR: 24.5515, Best model saved with validation loss: 0.3357 at ../Models/best_FocusNet_norm.pth
# Epoch [70/2000], Train Loss: 0.2437, Valid Loss: 0.3436, Valid SSIM: 0.7902, Valid PSNR: 24.5947
# Epoch [71/2000], Train Loss: 0.2432, Valid Loss: 0.3348, Valid SSIM: 0.7898, Valid PSNR: 24.5464, Best model saved with validation loss: 0.3348 at ../Models/best_FocusNet_norm.pth
# Epoch [72/2000], Train Loss: 0.2439, Valid Loss: 0.3364, Valid SSIM: 0.7899, Valid PSNR: 24.6195
# Epoch [73/2000], Train Loss: 0.2440, Valid Loss: 0.3364, Valid SSIM: 0.7875, Valid PSNR: 24.5753
# Epoch [74/2000], Train Loss: 0.2450, Valid Loss: 0.3348, Valid SSIM: 0.7796, Valid PSNR: 24.2183
# Epoch [75/2000], Train Loss: 0.2447, Valid Loss: 0.3350, Valid SSIM: 0.7891, Valid PSNR: 24.6216
# Epoch [76/2000], Train Loss: 0.2461, Valid Loss: 0.3325, Valid SSIM: 0.7822, Valid PSNR: 24.3933, Best model saved with validation loss: 0.3325 at ../Models/best_FocusNet_norm.pth
# Epoch [77/2000], Train Loss: 0.2466, Valid Loss: 0.3343, Valid SSIM: 0.7809, Valid PSNR: 24.3519
# Epoch [78/2000], Train Loss: 0.2489, Valid Loss: 0.3390, Valid SSIM: 0.7969, Valid PSNR: 24.8467
# Epoch [79/2000], Train Loss: 0.2482, Valid Loss: 0.3441, Valid SSIM: 0.7859, Valid PSNR: 24.2649
# Epoch [80/2000], Train Loss: 0.2498, Valid Loss: 0.3500, Valid SSIM: 0.7949, Valid PSNR: 24.5602
# Epoch [81/2000], Train Loss: 0.2495, Valid Loss: 0.3413, Valid SSIM: 0.7944, Valid PSNR: 24.7458
# Epoch [82/2000], Train Loss: 0.2516, Valid Loss: 0.3251, Valid SSIM: 0.7953, Valid PSNR: 24.9921, Best model saved with validation loss: 0.3251 at ../Models/best_FocusNet_norm.pth
# Epoch [83/2000], Train Loss: 0.2541, Valid Loss: 0.3303, Valid SSIM: 0.7815, Valid PSNR: 24.5237
# Epoch [84/2000], Train Loss: 0.2545, Valid Loss: 0.3231, Valid SSIM: 0.7868, Valid PSNR: 24.6953, Best model saved with validation loss: 0.3231 at ../Models/best_FocusNet_norm.pth
# Epoch [85/2000], Train Loss: 0.2589, Valid Loss: 0.3448, Valid SSIM: 0.7879, Valid PSNR: 24.6233
# Epoch [86/2000], Train Loss: 0.2578, Valid Loss: 0.3203, Valid SSIM: 0.7915, Valid PSNR: 24.6568, Best model saved with validation loss: 0.3203 at ../Models/best_FocusNet_norm.pth
# Epoch [87/2000], Train Loss: 0.2580, Valid Loss: 0.3453, Valid SSIM: 0.7803, Valid PSNR: 24.0986
# Epoch [88/2000], Train Loss: 0.2577, Valid Loss: 0.3418, Valid SSIM: 0.7919, Valid PSNR: 24.4860
# Epoch [89/2000], Train Loss: 0.2612, Valid Loss: 0.3195, Valid SSIM: 0.7867, Valid PSNR: 24.7184, Best model saved with validation loss: 0.3195 at ../Models/best_FocusNet_norm.pth
# Epoch [90/2000], Train Loss: 0.2622, Valid Loss: 0.3529, Valid SSIM: 0.7807, Valid PSNR: 24.2516
# Epoch [91/2000], Train Loss: 0.2675, Valid Loss: 0.3397, Valid SSIM: 0.7891, Valid PSNR: 24.5439
# Epoch [92/2000], Train Loss: 0.2678, Valid Loss: 0.3501, Valid SSIM: 0.7862, Valid PSNR: 24.1531
# Epoch [93/2000], Train Loss: 0.2637, Valid Loss: 0.3315, Valid SSIM: 0.7725, Valid PSNR: 24.2155
# Epoch [94/2000], Train Loss: 0.2686, Valid Loss: 0.3223, Valid SSIM: 0.7737, Valid PSNR: 24.5361
# Epoch [95/2000], Train Loss: 0.2688, Valid Loss: 0.3389, Valid SSIM: 0.7813, Valid PSNR: 24.2819
# Epoch [96/2000], Train Loss: 0.2669, Valid Loss: 0.3443, Valid SSIM: 0.7816, Valid PSNR: 24.2055
# Epoch [97/2000], Train Loss: 0.2663, Valid Loss: 0.3418, Valid SSIM: 0.7918, Valid PSNR: 24.5278
# Epoch [98/2000], Train Loss: 0.2799, Valid Loss: 0.3307, Valid SSIM: 0.7650, Valid PSNR: 24.1178
# Epoch [99/2000], Train Loss: 0.2680, Valid Loss: 0.3319, Valid SSIM: 0.7758, Valid PSNR: 24.1368
# Epoch [100/2000], Train Loss: 0.2719, Valid Loss: 0.3267, Valid SSIM: 0.7831, Valid PSNR: 24.3384
# Epoch [101/2000], Train Loss: 0.2761, Valid Loss: 0.3292, Valid SSIM: 0.8032, Valid PSNR: 24.8570
# Epoch [102/2000], Train Loss: 0.2703, Valid Loss: 0.3165, Valid SSIM: 0.7776, Valid PSNR: 24.5032, Best model saved with validation loss: 0.3165 at ../Models/best_FocusNet_norm.pth
# Epoch [103/2000], Train Loss: 0.2711, Valid Loss: 0.3332, Valid SSIM: 0.7874, Valid PSNR: 24.3685
# Epoch [104/2000], Train Loss: 0.2712, Valid Loss: 0.3131, Valid SSIM: 0.8033, Valid PSNR: 25.0367, Best model saved with validation loss: 0.3131 at ../Models/best_FocusNet_norm.pth
# Epoch [105/2000], Train Loss: 0.2731, Valid Loss: 0.3336, Valid SSIM: 0.7839, Valid PSNR: 24.2593
# Epoch [106/2000], Train Loss: 0.2714, Valid Loss: 0.3358, Valid SSIM: 0.8110, Valid PSNR: 25.3327
# Epoch [107/2000], Train Loss: 0.2759, Valid Loss: 0.3280, Valid SSIM: 0.7721, Valid PSNR: 24.1808
# Epoch [108/2000], Train Loss: 0.2722, Valid Loss: 0.3338, Valid SSIM: 0.8000, Valid PSNR: 24.5529
# Epoch [109/2000], Train Loss: 0.2685, Valid Loss: 0.3475, Valid SSIM: 0.8103, Valid PSNR: 25.1997
# Epoch [110/2000], Train Loss: 0.2734, Valid Loss: 0.3236, Valid SSIM: 0.7939, Valid PSNR: 24.6414
# Epoch [111/2000], Train Loss: 0.2703, Valid Loss: 0.3172, Valid SSIM: 0.7931, Valid PSNR: 24.6734
# Epoch [112/2000], Train Loss: 0.2662, Valid Loss: 0.3332, Valid SSIM: 0.7973, Valid PSNR: 24.5097
# Epoch [113/2000], Train Loss: 0.2685, Valid Loss: 0.3592, Valid SSIM: 0.7997, Valid PSNR: 24.8927
# Epoch [114/2000], Train Loss: 0.2677, Valid Loss: 0.3449, Valid SSIM: 0.7880, Valid PSNR: 23.9412
# Epoch [115/2000], Train Loss: 0.2694, Valid Loss: 0.3192, Valid SSIM: 0.8038, Valid PSNR: 24.8444
# Epoch [116/2000], Train Loss: 0.2632, Valid Loss: 0.3255, Valid SSIM: 0.8041, Valid PSNR: 24.9356
# Epoch [117/2000], Train Loss: 0.2669, Valid Loss: 0.3283, Valid SSIM: 0.7900, Valid PSNR: 24.5582
# Epoch [118/2000], Train Loss: 0.2611, Valid Loss: 0.3241, Valid SSIM: 0.7948, Valid PSNR: 24.6133
# Epoch [119/2000], Train Loss: 0.2611, Valid Loss: 0.3198, Valid SSIM: 0.8011, Valid PSNR: 24.7816
# Epoch [120/2000], Train Loss: 0.2564, Valid Loss: 0.3401, Valid SSIM: 0.7911, Valid PSNR: 24.2345
# Epoch [121/2000], Train Loss: 0.2644, Valid Loss: 0.3197, Valid SSIM: 0.8189, Valid PSNR: 25.5440
# Epoch [122/2000], Train Loss: 0.2594, Valid Loss: 0.3384, Valid SSIM: 0.8102, Valid PSNR: 25.1222
# Epoch [123/2000], Train Loss: 0.2593, Valid Loss: 0.3031, Valid SSIM: 0.8072, Valid PSNR: 25.2572, Best model saved with validation loss: 0.3031 at ../Models/best_FocusNet_norm.pth
# Epoch [124/2000], Train Loss: 0.2536, Valid Loss: 0.3272, Valid SSIM: 0.8052, Valid PSNR: 24.5930
# Epoch [125/2000], Train Loss: 0.2513, Valid Loss: 0.3105, Valid SSIM: 0.8047, Valid PSNR: 25.1276
# Epoch [126/2000], Train Loss: 0.2535, Valid Loss: 0.3447, Valid SSIM: 0.8002, Valid PSNR: 24.6918
# Epoch [127/2000], Train Loss: 0.2504, Valid Loss: 0.3491, Valid SSIM: 0.8068, Valid PSNR: 24.6558
# Epoch [128/2000], Train Loss: 0.2527, Valid Loss: 0.3533, Valid SSIM: 0.8031, Valid PSNR: 24.8336
# Epoch [129/2000], Train Loss: 0.2513, Valid Loss: 0.3261, Valid SSIM: 0.8169, Valid PSNR: 25.5618
# Epoch [130/2000], Train Loss: 0.2462, Valid Loss: 0.3343, Valid SSIM: 0.8052, Valid PSNR: 24.7889
# Epoch [131/2000], Train Loss: 0.2474, Valid Loss: 0.3083, Valid SSIM: 0.8174, Valid PSNR: 25.3570
# Epoch [132/2000], Train Loss: 0.2440, Valid Loss: 0.3445, Valid SSIM: 0.8023, Valid PSNR: 25.1371
# Epoch [133/2000], Train Loss: 0.2458, Valid Loss: 0.3448, Valid SSIM: 0.8112, Valid PSNR: 24.7983
# Epoch [134/2000], Train Loss: 0.2419, Valid Loss: 0.3118, Valid SSIM: 0.8195, Valid PSNR: 25.4140
# Epoch [135/2000], Train Loss: 0.2375, Valid Loss: 0.3074, Valid SSIM: 0.8137, Valid PSNR: 25.3969
# Epoch [136/2000], Train Loss: 0.2383, Valid Loss: 0.3106, Valid SSIM: 0.8192, Valid PSNR: 25.2547
# Epoch [137/2000], Train Loss: 0.2351, Valid Loss: 0.3133, Valid SSIM: 0.8168, Valid PSNR: 25.3260
# Epoch [138/2000], Train Loss: 0.2359, Valid Loss: 0.3146, Valid SSIM: 0.8287, Valid PSNR: 25.6572
# Epoch [139/2000], Train Loss: 0.2320, Valid Loss: 0.3406, Valid SSIM: 0.8224, Valid PSNR: 25.1657
# Epoch [140/2000], Train Loss: 0.2295, Valid Loss: 0.3117, Valid SSIM: 0.8276, Valid PSNR: 25.6521
# Epoch [141/2000], Train Loss: 0.2274, Valid Loss: 0.3061, Valid SSIM: 0.8207, Valid PSNR: 25.6047
# Epoch [142/2000], Train Loss: 0.2254, Valid Loss: 0.2994, Valid SSIM: 0.8260, Valid PSNR: 25.9758, Best model saved with validation loss: 0.2994 at ../Models/best_FocusNet_norm.pth
# Epoch [143/2000], Train Loss: 0.2249, Valid Loss: 0.3203, Valid SSIM: 0.8230, Valid PSNR: 25.2905
# Epoch [144/2000], Train Loss: 0.2231, Valid Loss: 0.3127, Valid SSIM: 0.8290, Valid PSNR: 25.8093
# Epoch [145/2000], Train Loss: 0.2223, Valid Loss: 0.3207, Valid SSIM: 0.8277, Valid PSNR: 25.5876
# Epoch [146/2000], Train Loss: 0.2206, Valid Loss: 0.3136, Valid SSIM: 0.8260, Valid PSNR: 25.5268
# Epoch [147/2000], Train Loss: 0.2201, Valid Loss: 0.2934, Valid SSIM: 0.8211, Valid PSNR: 25.6548, Best model saved with validation loss: 0.2934 at ../Models/best_FocusNet_norm.pth
# Epoch [148/2000], Train Loss: 0.2199, Valid Loss: 0.3139, Valid SSIM: 0.8201, Valid PSNR: 25.3698
# Epoch [149/2000], Train Loss: 0.2179, Valid Loss: 0.3042, Valid SSIM: 0.8263, Valid PSNR: 25.5305
# Epoch [150/2000], Train Loss: 0.2157, Valid Loss: 0.3226, Valid SSIM: 0.8285, Valid PSNR: 25.5606
# Epoch [151/2000], Train Loss: 0.2145, Valid Loss: 0.2987, Valid SSIM: 0.8330, Valid PSNR: 26.0061
# Epoch [152/2000], Train Loss: 0.2125, Valid Loss: 0.3402, Valid SSIM: 0.8245, Valid PSNR: 25.1862
# Epoch [153/2000], Train Loss: 0.2122, Valid Loss: 0.3154, Valid SSIM: 0.8194, Valid PSNR: 25.3095
# Epoch [154/2000], Train Loss: 0.2102, Valid Loss: 0.3007, Valid SSIM: 0.8237, Valid PSNR: 25.5772
# Epoch [155/2000], Train Loss: 0.2091, Valid Loss: 0.3036, Valid SSIM: 0.8347, Valid PSNR: 25.7921
# Epoch [156/2000], Train Loss: 0.2081, Valid Loss: 0.3078, Valid SSIM: 0.8263, Valid PSNR: 25.6597
# Epoch [157/2000], Train Loss: 0.2072, Valid Loss: 0.3034, Valid SSIM: 0.8293, Valid PSNR: 25.6904
# Epoch [158/2000], Train Loss: 0.2052, Valid Loss: 0.3095, Valid SSIM: 0.8325, Valid PSNR: 25.6220
# Epoch [159/2000], Train Loss: 0.2039, Valid Loss: 0.3072, Valid SSIM: 0.8329, Valid PSNR: 25.8486
# Epoch [160/2000], Train Loss: 0.2033, Valid Loss: 0.3044, Valid SSIM: 0.8342, Valid PSNR: 25.7990
# Epoch [161/2000], Train Loss: 0.2020, Valid Loss: 0.3022, Valid SSIM: 0.8351, Valid PSNR: 25.9120
# Epoch [162/2000], Train Loss: 0.2014, Valid Loss: 0.2981, Valid SSIM: 0.8320, Valid PSNR: 25.8245
# Epoch [163/2000], Train Loss: 0.2002, Valid Loss: 0.3110, Valid SSIM: 0.8367, Valid PSNR: 25.7897
# Epoch [164/2000], Train Loss: 0.1993, Valid Loss: 0.3027, Valid SSIM: 0.8350, Valid PSNR: 25.9239
# Epoch [165/2000], Train Loss: 0.1988, Valid Loss: 0.3060, Valid SSIM: 0.8358, Valid PSNR: 25.8136
# Epoch [166/2000], Train Loss: 0.1981, Valid Loss: 0.3065, Valid SSIM: 0.8374, Valid PSNR: 25.8799
# Epoch [167/2000], Train Loss: 0.1975, Valid Loss: 0.3014, Valid SSIM: 0.8382, Valid PSNR: 25.9008
# Epoch [168/2000], Train Loss: 0.1968, Valid Loss: 0.3060, Valid SSIM: 0.8380, Valid PSNR: 25.8399
# Epoch [169/2000], Train Loss: 0.1961, Valid Loss: 0.3050, Valid SSIM: 0.8377, Valid PSNR: 25.8797
# Epoch [170/2000], Train Loss: 0.1956, Valid Loss: 0.3032, Valid SSIM: 0.8377, Valid PSNR: 25.8676
# Epoch [171/2000], Train Loss: 0.1952, Valid Loss: 0.3039, Valid SSIM: 0.8387, Valid PSNR: 25.9047
# Epoch [172/2000], Train Loss: 0.1949, Valid Loss: 0.3033, Valid SSIM: 0.8384, Valid PSNR: 25.8655
# Epoch [173/2000], Train Loss: 0.1945, Valid Loss: 0.3044, Valid SSIM: 0.8380, Valid PSNR: 25.8287
# Epoch [174/2000], Train Loss: 0.1943, Valid Loss: 0.3033, Valid SSIM: 0.8383, Valid PSNR: 25.8588
# Epoch [175/2000], Train Loss: 0.1941, Valid Loss: 0.3036, Valid SSIM: 0.8383, Valid PSNR: 25.8705
# Epoch [176/2000], Train Loss: 0.1939, Valid Loss: 0.3048, Valid SSIM: 0.8387, Valid PSNR: 25.8629
# Epoch [177/2000], Train Loss: 0.1938, Valid Loss: 0.3048, Valid SSIM: 0.8387, Valid PSNR: 25.8768
# Epoch [178/2000], Train Loss: 0.1937, Valid Loss: 0.3043, Valid SSIM: 0.8386, Valid PSNR: 25.8696
# Epoch [179/2000], Train Loss: 0.1936, Valid Loss: 0.3048, Valid SSIM: 0.8386, Valid PSNR: 25.8628
# Epoch [180/2000], Train Loss: 0.1936, Valid Loss: 0.3046, Valid SSIM: 0.8386, Valid PSNR: 25.8655
# Epoch [181/2000], Train Loss: 0.1936, Valid Loss: 0.3046, Valid SSIM: 0.8386, Valid PSNR: 25.8655
# Epoch [182/2000], Train Loss: 0.1936, Valid Loss: 0.3048, Valid SSIM: 0.8386, Valid PSNR: 25.8657
# Epoch [183/2000], Train Loss: 0.1936, Valid Loss: 0.3045, Valid SSIM: 0.8385, Valid PSNR: 25.8651
# Epoch [184/2000], Train Loss: 0.1936, Valid Loss: 0.3048, Valid SSIM: 0.8384, Valid PSNR: 25.8531
# Epoch [185/2000], Train Loss: 0.1937, Valid Loss: 0.3053, Valid SSIM: 0.8383, Valid PSNR: 25.8615
# Epoch [186/2000], Train Loss: 0.1937, Valid Loss: 0.3034, Valid SSIM: 0.8387, Valid PSNR: 25.8808
# Epoch [187/2000], Train Loss: 0.1937, Valid Loss: 0.3042, Valid SSIM: 0.8386, Valid PSNR: 25.8512
# Epoch [188/2000], Train Loss: 0.1937, Valid Loss: 0.3048, Valid SSIM: 0.8389, Valid PSNR: 25.8378
# Epoch [189/2000], Train Loss: 0.1937, Valid Loss: 0.3043, Valid SSIM: 0.8390, Valid PSNR: 25.8539
# Epoch [190/2000], Train Loss: 0.1938, Valid Loss: 0.3026, Valid SSIM: 0.8391, Valid PSNR: 25.8488
# Epoch [191/2000], Train Loss: 0.1939, Valid Loss: 0.3046, Valid SSIM: 0.8386, Valid PSNR: 25.8396
# Epoch [192/2000], Train Loss: 0.1940, Valid Loss: 0.3040, Valid SSIM: 0.8392, Valid PSNR: 25.8445
# Epoch [193/2000], Train Loss: 0.1941, Valid Loss: 0.3049, Valid SSIM: 0.8389, Valid PSNR: 25.8647
# Epoch [194/2000], Train Loss: 0.1941, Valid Loss: 0.3061, Valid SSIM: 0.8403, Valid PSNR: 25.8400
# Epoch [195/2000], Train Loss: 0.1947, Valid Loss: 0.3063, Valid SSIM: 0.8373, Valid PSNR: 25.7559
# Epoch [196/2000], Train Loss: 0.1950, Valid Loss: 0.3039, Valid SSIM: 0.8397, Valid PSNR: 25.8557
# Epoch [197/2000], Train Loss: 0.1946, Valid Loss: 0.3052, Valid SSIM: 0.8418, Valid PSNR: 25.9460
# Epoch [198/2000], Train Loss: 0.1953, Valid Loss: 0.3039, Valid SSIM: 0.8408, Valid PSNR: 25.8392
# Epoch [199/2000], Train Loss: 0.1960, Valid Loss: 0.2955, Valid SSIM: 0.8404, Valid PSNR: 25.9141
# Epoch [200/2000], Train Loss: 0.1969, Valid Loss: 0.3038, Valid SSIM: 0.8406, Valid PSNR: 25.7656
# Epoch [201/2000], Train Loss: 0.1972, Valid Loss: 0.2941, Valid SSIM: 0.8371, Valid PSNR: 25.8221
# Epoch [202/2000], Train Loss: 0.1971, Valid Loss: 0.3006, Valid SSIM: 0.8391, Valid PSNR: 25.8858
# Epoch [203/2000], Train Loss: 0.1982, Valid Loss: 0.2985, Valid SSIM: 0.8404, Valid PSNR: 25.9934
# Epoch [204/2000], Train Loss: 0.1984, Valid Loss: 0.2915, Valid SSIM: 0.8405, Valid PSNR: 25.9911, Best model saved with validation loss: 0.2915 at ../Models/best_FocusNet_norm.pth
# Epoch [205/2000], Train Loss: 0.1994, Valid Loss: 0.2982, Valid SSIM: 0.8419, Valid PSNR: 25.9709
# Epoch [206/2000], Train Loss: 0.1996, Valid Loss: 0.3028, Valid SSIM: 0.8390, Valid PSNR: 25.7836
# Epoch [207/2000], Train Loss: 0.1998, Valid Loss: 0.2977, Valid SSIM: 0.8364, Valid PSNR: 25.7751
# Epoch [208/2000], Train Loss: 0.2040, Valid Loss: 0.3015, Valid SSIM: 0.8318, Valid PSNR: 25.6876
# Epoch [209/2000], Train Loss: 0.2005, Valid Loss: 0.3153, Valid SSIM: 0.8325, Valid PSNR: 25.6646
# Epoch [210/2000], Train Loss: 0.2026, Valid Loss: 0.2991, Valid SSIM: 0.8350, Valid PSNR: 25.6374
# Epoch [211/2000], Train Loss: 0.2024, Valid Loss: 0.2983, Valid SSIM: 0.8384, Valid PSNR: 25.9140
# Epoch [212/2000], Train Loss: 0.2057, Valid Loss: 0.2978, Valid SSIM: 0.8306, Valid PSNR: 25.5299
# Epoch [213/2000], Train Loss: 0.2068, Valid Loss: 0.2957, Valid SSIM: 0.8293, Valid PSNR: 25.6788
# Epoch [214/2000], Train Loss: 0.2051, Valid Loss: 0.3105, Valid SSIM: 0.8433, Valid PSNR: 25.8928
# Epoch [215/2000], Train Loss: 0.2020, Valid Loss: 0.2953, Valid SSIM: 0.8289, Valid PSNR: 25.7968
# Epoch [216/2000], Train Loss: 0.2062, Valid Loss: 0.2942, Valid SSIM: 0.8374, Valid PSNR: 25.9559
# Epoch [217/2000], Train Loss: 0.2081, Valid Loss: 0.2924, Valid SSIM: 0.8414, Valid PSNR: 26.0310
# Epoch [218/2000], Train Loss: 0.2064, Valid Loss: 0.3148, Valid SSIM: 0.8365, Valid PSNR: 25.6880
# Epoch [219/2000], Train Loss: 0.2057, Valid Loss: 0.2935, Valid SSIM: 0.8375, Valid PSNR: 25.5230
# Epoch [220/2000], Train Loss: 0.2084, Valid Loss: 0.2988, Valid SSIM: 0.8393, Valid PSNR: 25.9822
# Epoch [221/2000], Train Loss: 0.2087, Valid Loss: 0.3106, Valid SSIM: 0.8259, Valid PSNR: 25.3412
# Epoch [222/2000], Train Loss: 0.2089, Valid Loss: 0.3487, Valid SSIM: 0.8295, Valid PSNR: 25.4502
# Epoch [223/2000], Train Loss: 0.2087, Valid Loss: 0.3019, Valid SSIM: 0.8267, Valid PSNR: 25.5791
# Epoch [224/2000], Train Loss: 0.2138, Valid Loss: 0.2930, Valid SSIM: 0.8300, Valid PSNR: 25.5187
# Epoch [225/2000], Train Loss: 0.2109, Valid Loss: 0.2957, Valid SSIM: 0.8341, Valid PSNR: 25.8084
# Epoch [226/2000], Train Loss: 0.2103, Valid Loss: 0.2903, Valid SSIM: 0.8319, Valid PSNR: 25.7754, Best model saved with validation loss: 0.2903 at ../Models/best_FocusNet_norm.pth
# Epoch [227/2000], Train Loss: 0.2097, Valid Loss: 0.3068, Valid SSIM: 0.8358, Valid PSNR: 25.8440
# Epoch [228/2000], Train Loss: 0.2155, Valid Loss: 0.2873, Valid SSIM: 0.8388, Valid PSNR: 25.8865, Best model saved with validation loss: 0.2873 at ../Models/best_FocusNet_norm.pth
# Epoch [229/2000], Train Loss: 0.2107, Valid Loss: 0.2916, Valid SSIM: 0.8434, Valid PSNR: 26.2668
# Epoch [230/2000], Train Loss: 0.2126, Valid Loss: 0.3004, Valid SSIM: 0.8274, Valid PSNR: 25.3401
# Epoch [231/2000], Train Loss: 0.2139, Valid Loss: 0.3047, Valid SSIM: 0.8321, Valid PSNR: 25.7430
# Epoch [232/2000], Train Loss: 0.2088, Valid Loss: 0.3075, Valid SSIM: 0.8330, Valid PSNR: 25.6029
# Epoch [233/2000], Train Loss: 0.2087, Valid Loss: 0.2970, Valid SSIM: 0.8375, Valid PSNR: 26.1161
# Epoch [234/2000], Train Loss: 0.2117, Valid Loss: 0.2958, Valid SSIM: 0.8360, Valid PSNR: 26.1565
# Epoch [235/2000], Train Loss: 0.2110, Valid Loss: 0.3162, Valid SSIM: 0.8337, Valid PSNR: 25.8593
# Epoch [236/2000], Train Loss: 0.2065, Valid Loss: 0.2953, Valid SSIM: 0.8326, Valid PSNR: 25.7454
# Epoch [237/2000], Train Loss: 0.2101, Valid Loss: 0.2965, Valid SSIM: 0.8409, Valid PSNR: 26.1588
# Epoch [238/2000], Train Loss: 0.2073, Valid Loss: 0.2883, Valid SSIM: 0.8298, Valid PSNR: 25.8442
# Epoch [239/2000], Train Loss: 0.2120, Valid Loss: 0.2943, Valid SSIM: 0.8421, Valid PSNR: 26.2113
# Epoch [240/2000], Train Loss: 0.2081, Valid Loss: 0.2938, Valid SSIM: 0.8416, Valid PSNR: 26.0887
# Epoch [241/2000], Train Loss: 0.2059, Valid Loss: 0.2849, Valid SSIM: 0.8403, Valid PSNR: 26.1569, Best model saved with validation loss: 0.2849 at ../Models/best_FocusNet_norm.pth
# Epoch [242/2000], Train Loss: 0.2072, Valid Loss: 0.3041, Valid SSIM: 0.8441, Valid PSNR: 25.9251
# Epoch [243/2000], Train Loss: 0.2089, Valid Loss: 0.2927, Valid SSIM: 0.8391, Valid PSNR: 25.9303
# Epoch [244/2000], Train Loss: 0.2060, Valid Loss: 0.2875, Valid SSIM: 0.8428, Valid PSNR: 26.0803
# Epoch [245/2000], Train Loss: 0.2028, Valid Loss: 0.3025, Valid SSIM: 0.8447, Valid PSNR: 26.3161
# Epoch [246/2000], Train Loss: 0.2049, Valid Loss: 0.2912, Valid SSIM: 0.8434, Valid PSNR: 26.0720
# Epoch [247/2000], Train Loss: 0.2052, Valid Loss: 0.2842, Valid SSIM: 0.8445, Valid PSNR: 26.2975, Best model saved with validation loss: 0.2842 at ../Models/best_FocusNet_norm.pth
# Epoch [248/2000], Train Loss: 0.1985, Valid Loss: 0.2961, Valid SSIM: 0.8431, Valid PSNR: 26.3170
# Epoch [249/2000], Train Loss: 0.2025, Valid Loss: 0.2899, Valid SSIM: 0.8470, Valid PSNR: 26.2374
# Epoch [250/2000], Train Loss: 0.2026, Valid Loss: 0.3087, Valid SSIM: 0.8432, Valid PSNR: 26.1892
# Epoch [251/2000], Train Loss: 0.1991, Valid Loss: 0.2773, Valid SSIM: 0.8399, Valid PSNR: 26.0439, Best model saved with validation loss: 0.2773 at ../Models/best_FocusNet_norm.pth
# Epoch [252/2000], Train Loss: 0.1983, Valid Loss: 0.2826, Valid SSIM: 0.8427, Valid PSNR: 26.2884
# Epoch [253/2000], Train Loss: 0.1966, Valid Loss: 0.3033, Valid SSIM: 0.8383, Valid PSNR: 25.8060
# Epoch [254/2000], Train Loss: 0.2003, Valid Loss: 0.2898, Valid SSIM: 0.8402, Valid PSNR: 25.7423
# Epoch [255/2000], Train Loss: 0.1938, Valid Loss: 0.2935, Valid SSIM: 0.8494, Valid PSNR: 26.5059
# Epoch [256/2000], Train Loss: 0.1914, Valid Loss: 0.2924, Valid SSIM: 0.8483, Valid PSNR: 26.2548
# Epoch [257/2000], Train Loss: 0.1948, Valid Loss: 0.2941, Valid SSIM: 0.8466, Valid PSNR: 26.2019
# Epoch [258/2000], Train Loss: 0.1928, Valid Loss: 0.2815, Valid SSIM: 0.8552, Valid PSNR: 26.4609
# Epoch [259/2000], Train Loss: 0.1917, Valid Loss: 0.2941, Valid SSIM: 0.8498, Valid PSNR: 26.1773
# Epoch [260/2000], Train Loss: 0.1908, Valid Loss: 0.2912, Valid SSIM: 0.8428, Valid PSNR: 26.2217
# Epoch [261/2000], Train Loss: 0.1895, Valid Loss: 0.2803, Valid SSIM: 0.8471, Valid PSNR: 26.2712
# Epoch [262/2000], Train Loss: 0.1865, Valid Loss: 0.2931, Valid SSIM: 0.8469, Valid PSNR: 26.1875
# Epoch [263/2000], Train Loss: 0.1863, Valid Loss: 0.2818, Valid SSIM: 0.8560, Valid PSNR: 26.6006
# Epoch [264/2000], Train Loss: 0.1851, Valid Loss: 0.2853, Valid SSIM: 0.8525, Valid PSNR: 26.6011
# Epoch [265/2000], Train Loss: 0.1838, Valid Loss: 0.2830, Valid SSIM: 0.8534, Valid PSNR: 26.6360
# Epoch [266/2000], Train Loss: 0.1823, Valid Loss: 0.2819, Valid SSIM: 0.8490, Valid PSNR: 26.3819
# Epoch [267/2000], Train Loss: 0.1819, Valid Loss: 0.2760, Valid SSIM: 0.8545, Valid PSNR: 26.6585, Best model saved with validation loss: 0.2760 at ../Models/best_FocusNet_norm.pth
# Epoch [268/2000], Train Loss: 0.1844, Valid Loss: 0.2825, Valid SSIM: 0.8555, Valid PSNR: 26.4769
# Epoch [269/2000], Train Loss: 0.1788, Valid Loss: 0.2746, Valid SSIM: 0.8611, Valid PSNR: 26.6982, Best model saved with validation loss: 0.2746 at ../Models/best_FocusNet_norm.pth
# Epoch [270/2000], Train Loss: 0.1781, Valid Loss: 0.2843, Valid SSIM: 0.8590, Valid PSNR: 26.8326
# Epoch [271/2000], Train Loss: 0.1768, Valid Loss: 0.2744, Valid SSIM: 0.8557, Valid PSNR: 26.6852, Best model saved with validation loss: 0.2744 at ../Models/best_FocusNet_norm.pth
# Epoch [272/2000], Train Loss: 0.1766, Valid Loss: 0.2719, Valid SSIM: 0.8523, Valid PSNR: 26.4776, Best model saved with validation loss: 0.2719 at ../Models/best_FocusNet_norm.pth
# Epoch [273/2000], Train Loss: 0.1746, Valid Loss: 0.2768, Valid SSIM: 0.8588, Valid PSNR: 26.8325
# Epoch [274/2000], Train Loss: 0.1746, Valid Loss: 0.2836, Valid SSIM: 0.8558, Valid PSNR: 26.7322
# Epoch [275/2000], Train Loss: 0.1741, Valid Loss: 0.2705, Valid SSIM: 0.8599, Valid PSNR: 26.9128, Best model saved with validation loss: 0.2705 at ../Models/best_FocusNet_norm.pth
# Epoch [276/2000], Train Loss: 0.1725, Valid Loss: 0.2784, Valid SSIM: 0.8575, Valid PSNR: 26.6849
# Epoch [277/2000], Train Loss: 0.1717, Valid Loss: 0.2734, Valid SSIM: 0.8560, Valid PSNR: 26.6320
# Epoch [278/2000], Train Loss: 0.1708, Valid Loss: 0.2745, Valid SSIM: 0.8607, Valid PSNR: 26.8462
# Epoch [279/2000], Train Loss: 0.1701, Valid Loss: 0.2637, Valid SSIM: 0.8620, Valid PSNR: 26.9360, Best model saved with validation loss: 0.2637 at ../Models/best_FocusNet_norm.pth
# Epoch [280/2000], Train Loss: 0.1691, Valid Loss: 0.2724, Valid SSIM: 0.8602, Valid PSNR: 26.7349
# Epoch [281/2000], Train Loss: 0.1685, Valid Loss: 0.2738, Valid SSIM: 0.8569, Valid PSNR: 26.6205
# Epoch [282/2000], Train Loss: 0.1680, Valid Loss: 0.2766, Valid SSIM: 0.8605, Valid PSNR: 26.7309
# Epoch [283/2000], Train Loss: 0.1669, Valid Loss: 0.2709, Valid SSIM: 0.8629, Valid PSNR: 26.9722
# Epoch [284/2000], Train Loss: 0.1664, Valid Loss: 0.2721, Valid SSIM: 0.8615, Valid PSNR: 26.9621
# Epoch [285/2000], Train Loss: 0.1659, Valid Loss: 0.2709, Valid SSIM: 0.8602, Valid PSNR: 26.7496
# Epoch [286/2000], Train Loss: 0.1653, Valid Loss: 0.2705, Valid SSIM: 0.8638, Valid PSNR: 27.0032
# Epoch [287/2000], Train Loss: 0.1646, Valid Loss: 0.2724, Valid SSIM: 0.8626, Valid PSNR: 26.9038
# Epoch [288/2000], Train Loss: 0.1643, Valid Loss: 0.2726, Valid SSIM: 0.8613, Valid PSNR: 26.8758
# Epoch [289/2000], Train Loss: 0.1640, Valid Loss: 0.2709, Valid SSIM: 0.8623, Valid PSNR: 26.9046
# Epoch [290/2000], Train Loss: 0.1637, Valid Loss: 0.2717, Valid SSIM: 0.8631, Valid PSNR: 26.9805
# Epoch [291/2000], Train Loss: 0.1633, Valid Loss: 0.2695, Valid SSIM: 0.8632, Valid PSNR: 26.9392
# Epoch [292/2000], Train Loss: 0.1631, Valid Loss: 0.2716, Valid SSIM: 0.8639, Valid PSNR: 26.9559
# Epoch [293/2000], Train Loss: 0.1628, Valid Loss: 0.2721, Valid SSIM: 0.8637, Valid PSNR: 26.9598
# Epoch [294/2000], Train Loss: 0.1626, Valid Loss: 0.2712, Valid SSIM: 0.8631, Valid PSNR: 26.9099
# Epoch [295/2000], Train Loss: 0.1624, Valid Loss: 0.2709, Valid SSIM: 0.8635, Valid PSNR: 26.9500
# Epoch [296/2000], Train Loss: 0.1622, Valid Loss: 0.2700, Valid SSIM: 0.8639, Valid PSNR: 26.9594
# Epoch [297/2000], Train Loss: 0.1621, Valid Loss: 0.2706, Valid SSIM: 0.8640, Valid PSNR: 26.9706
# Epoch [298/2000], Train Loss: 0.1620, Valid Loss: 0.2704, Valid SSIM: 0.8639, Valid PSNR: 26.9612
# Epoch [299/2000], Train Loss: 0.1620, Valid Loss: 0.2704, Valid SSIM: 0.8639, Valid PSNR: 26.9616
# Epoch [300/2000], Train Loss: 0.1620, Valid Loss: 0.2705, Valid SSIM: 0.8639, Valid PSNR: 26.9630
# Epoch [301/2000], Train Loss: 0.1619, Valid Loss: 0.2705, Valid SSIM: 0.8639, Valid PSNR: 26.9630
# Epoch [302/2000], Train Loss: 0.1619, Valid Loss: 0.2705, Valid SSIM: 0.8639, Valid PSNR: 26.9638
# Epoch [303/2000], Train Loss: 0.1620, Valid Loss: 0.2706, Valid SSIM: 0.8640, Valid PSNR: 26.9683
# Epoch [304/2000], Train Loss: 0.1620, Valid Loss: 0.2705, Valid SSIM: 0.8639, Valid PSNR: 26.9644
# Epoch [305/2000], Train Loss: 0.1621, Valid Loss: 0.2704, Valid SSIM: 0.8639, Valid PSNR: 26.9573
# Epoch [306/2000], Train Loss: 0.1621, Valid Loss: 0.2703, Valid SSIM: 0.8642, Valid PSNR: 26.9677
# Epoch [307/2000], Train Loss: 0.1622, Valid Loss: 0.2698, Valid SSIM: 0.8640, Valid PSNR: 26.9644
# Epoch [308/2000], Train Loss: 0.1622, Valid Loss: 0.2706, Valid SSIM: 0.8635, Valid PSNR: 26.9519
# Epoch [309/2000], Train Loss: 0.1623, Valid Loss: 0.2707, Valid SSIM: 0.8639, Valid PSNR: 26.9770
# Epoch [310/2000], Train Loss: 0.1623, Valid Loss: 0.2722, Valid SSIM: 0.8644, Valid PSNR: 26.9825
# Epoch [311/2000], Train Loss: 0.1625, Valid Loss: 0.2698, Valid SSIM: 0.8643, Valid PSNR: 26.9806
# Epoch [312/2000], Train Loss: 0.1626, Valid Loss: 0.2716, Valid SSIM: 0.8647, Valid PSNR: 26.9615
# Epoch [313/2000], Train Loss: 0.1629, Valid Loss: 0.2745, Valid SSIM: 0.8638, Valid PSNR: 26.9678
# Epoch [314/2000], Train Loss: 0.1629, Valid Loss: 0.2701, Valid SSIM: 0.8638, Valid PSNR: 26.9281
# Epoch [315/2000], Train Loss: 0.1630, Valid Loss: 0.2706, Valid SSIM: 0.8642, Valid PSNR: 26.8929
# Epoch [316/2000], Train Loss: 0.1634, Valid Loss: 0.2699, Valid SSIM: 0.8643, Valid PSNR: 26.9499
# Epoch [317/2000], Train Loss: 0.1639, Valid Loss: 0.2704, Valid SSIM: 0.8649, Valid PSNR: 27.0542
# Epoch [318/2000], Train Loss: 0.1640, Valid Loss: 0.2695, Valid SSIM: 0.8640, Valid PSNR: 26.8580
# Epoch [319/2000], Train Loss: 0.1641, Valid Loss: 0.2737, Valid SSIM: 0.8621, Valid PSNR: 26.8266
# Epoch [320/2000], Train Loss: 0.1646, Valid Loss: 0.2658, Valid SSIM: 0.8643, Valid PSNR: 26.9457
# Epoch [321/2000], Train Loss: 0.1654, Valid Loss: 0.2770, Valid SSIM: 0.8612, Valid PSNR: 26.7634
# Epoch [322/2000], Train Loss: 0.1657, Valid Loss: 0.2715, Valid SSIM: 0.8644, Valid PSNR: 26.9939
# Epoch [323/2000], Train Loss: 0.1661, Valid Loss: 0.2740, Valid SSIM: 0.8634, Valid PSNR: 26.9006
# Epoch [324/2000], Train Loss: 0.1680, Valid Loss: 0.2736, Valid SSIM: 0.8648, Valid PSNR: 27.0000
# Epoch [325/2000], Train Loss: 0.1680, Valid Loss: 0.2774, Valid SSIM: 0.8610, Valid PSNR: 26.7692
# Epoch [326/2000], Train Loss: 0.1679, Valid Loss: 0.2766, Valid SSIM: 0.8629, Valid PSNR: 26.9334
# Epoch [327/2000], Train Loss: 0.1687, Valid Loss: 0.2721, Valid SSIM: 0.8582, Valid PSNR: 26.5199
# Epoch [328/2000], Train Loss: 0.1691, Valid Loss: 0.2754, Valid SSIM: 0.8591, Valid PSNR: 26.8274
# Epoch [329/2000], Train Loss: 0.1709, Valid Loss: 0.2859, Valid SSIM: 0.8576, Valid PSNR: 26.5970
# Epoch [330/2000], Train Loss: 0.1711, Valid Loss: 0.2753, Valid SSIM: 0.8625, Valid PSNR: 26.7386
# Epoch [331/2000], Train Loss: 0.1733, Valid Loss: 0.2645, Valid SSIM: 0.8644, Valid PSNR: 27.0043
# Epoch [332/2000], Train Loss: 0.1705, Valid Loss: 0.2870, Valid SSIM: 0.8554, Valid PSNR: 26.5063
# Epoch [333/2000], Train Loss: 0.1709, Valid Loss: 0.2655, Valid SSIM: 0.8625, Valid PSNR: 26.8854
# Epoch [334/2000], Train Loss: 0.1730, Valid Loss: 0.2676, Valid SSIM: 0.8634, Valid PSNR: 26.9051
# Epoch [335/2000], Train Loss: 0.1755, Valid Loss: 0.2708, Valid SSIM: 0.8662, Valid PSNR: 26.8641
# Epoch [336/2000], Train Loss: 0.1758, Valid Loss: 0.2656, Valid SSIM: 0.8598, Valid PSNR: 26.7277
# Epoch [337/2000], Train Loss: 0.1767, Valid Loss: 0.2732, Valid SSIM: 0.8621, Valid PSNR: 26.8138
# Epoch [338/2000], Train Loss: 0.1771, Valid Loss: 0.2765, Valid SSIM: 0.8624, Valid PSNR: 26.8286
# Epoch [339/2000], Train Loss: 0.1811, Valid Loss: 0.2730, Valid SSIM: 0.8585, Valid PSNR: 26.6591
# Epoch [340/2000], Train Loss: 0.1781, Valid Loss: 0.2612, Valid SSIM: 0.8544, Valid PSNR: 26.6701, Best model saved with validation loss: 0.2612 at ../Models/best_FocusNet_norm.pth
# Epoch [341/2000], Train Loss: 0.1803, Valid Loss: 0.2921, Valid SSIM: 0.8561, Valid PSNR: 26.4148
# Epoch [342/2000], Train Loss: 0.1836, Valid Loss: 0.2852, Valid SSIM: 0.8616, Valid PSNR: 26.7819
# Epoch [343/2000], Train Loss: 0.1779, Valid Loss: 0.2635, Valid SSIM: 0.8571, Valid PSNR: 26.7360
# Epoch [344/2000], Train Loss: 0.1796, Valid Loss: 0.3117, Valid SSIM: 0.8412, Valid PSNR: 25.4677
# Epoch [345/2000], Train Loss: 0.1830, Valid Loss: 0.2797, Valid SSIM: 0.8597, Valid PSNR: 26.4396
# Epoch [346/2000], Train Loss: 0.1824, Valid Loss: 0.2668, Valid SSIM: 0.8621, Valid PSNR: 26.9071
# Epoch [347/2000], Train Loss: 0.1823, Valid Loss: 0.2838, Valid SSIM: 0.8614, Valid PSNR: 26.7978
# Epoch [348/2000], Train Loss: 0.1843, Valid Loss: 0.2952, Valid SSIM: 0.8509, Valid PSNR: 26.4773
# Epoch [349/2000], Train Loss: 0.1873, Valid Loss: 0.3011, Valid SSIM: 0.8529, Valid PSNR: 26.4204
# Epoch [350/2000], Train Loss: 0.1823, Valid Loss: 0.2761, Valid SSIM: 0.8588, Valid PSNR: 26.7444
# Epoch [351/2000], Train Loss: 0.1846, Valid Loss: 0.2741, Valid SSIM: 0.8499, Valid PSNR: 26.3639
# Epoch [352/2000], Train Loss: 0.1863, Valid Loss: 0.2720, Valid SSIM: 0.8640, Valid PSNR: 26.9141
# Epoch [353/2000], Train Loss: 0.1848, Valid Loss: 0.2768, Valid SSIM: 0.8521, Valid PSNR: 26.5216
# Epoch [354/2000], Train Loss: 0.1844, Valid Loss: 0.2890, Valid SSIM: 0.8624, Valid PSNR: 26.5616
# Epoch [355/2000], Train Loss: 0.1839, Valid Loss: 0.2650, Valid SSIM: 0.8599, Valid PSNR: 26.7702
# Epoch [356/2000], Train Loss: 0.1828, Valid Loss: 0.2751, Valid SSIM: 0.8508, Valid PSNR: 26.1762
# Epoch [357/2000], Train Loss: 0.1822, Valid Loss: 0.2790, Valid SSIM: 0.8636, Valid PSNR: 26.6022
# Epoch [358/2000], Train Loss: 0.1859, Valid Loss: 0.2776, Valid SSIM: 0.8636, Valid PSNR: 26.6586
# Epoch [359/2000], Train Loss: 0.1829, Valid Loss: 0.2654, Valid SSIM: 0.8582, Valid PSNR: 26.4688
# Epoch [360/2000], Train Loss: 0.1862, Valid Loss: 0.2657, Valid SSIM: 0.8629, Valid PSNR: 26.7881
# Epoch [361/2000], Train Loss: 0.1855, Valid Loss: 0.2829, Valid SSIM: 0.8617, Valid PSNR: 26.8224
# Epoch [362/2000], Train Loss: 0.1852, Valid Loss: 0.2716, Valid SSIM: 0.8581, Valid PSNR: 26.6520
# Epoch [363/2000], Train Loss: 0.1824, Valid Loss: 0.2858, Valid SSIM: 0.8611, Valid PSNR: 26.4928
# Epoch [364/2000], Train Loss: 0.1804, Valid Loss: 0.2706, Valid SSIM: 0.8586, Valid PSNR: 26.7451
# Epoch [365/2000], Train Loss: 0.1813, Valid Loss: 0.2740, Valid SSIM: 0.8575, Valid PSNR: 26.7579
# Epoch [366/2000], Train Loss: 0.1814, Valid Loss: 0.3057, Valid SSIM: 0.8549, Valid PSNR: 26.3539
# Epoch [367/2000], Train Loss: 0.1799, Valid Loss: 0.2727, Valid SSIM: 0.8620, Valid PSNR: 26.6284
# Epoch [368/2000], Train Loss: 0.1776, Valid Loss: 0.2750, Valid SSIM: 0.8661, Valid PSNR: 26.7321
# Epoch [369/2000], Train Loss: 0.1813, Valid Loss: 0.2551, Valid SSIM: 0.8627, Valid PSNR: 26.8255, Best model saved with validation loss: 0.2551 at ../Models/best_FocusNet_norm.pth
# Epoch [370/2000], Train Loss: 0.1788, Valid Loss: 0.2798, Valid SSIM: 0.8619, Valid PSNR: 26.4932
# Epoch [371/2000], Train Loss: 0.1783, Valid Loss: 0.2758, Valid SSIM: 0.8635, Valid PSNR: 26.8115
# Epoch [372/2000], Train Loss: 0.1767, Valid Loss: 0.2644, Valid SSIM: 0.8660, Valid PSNR: 27.0982
# Epoch [373/2000], Train Loss: 0.1776, Valid Loss: 0.2696, Valid SSIM: 0.8631, Valid PSNR: 26.8839
# Epoch [374/2000], Train Loss: 0.1765, Valid Loss: 0.2638, Valid SSIM: 0.8616, Valid PSNR: 26.5894
# Epoch [375/2000], Train Loss: 0.1768, Valid Loss: 0.2839, Valid SSIM: 0.8589, Valid PSNR: 26.6271
# Epoch [376/2000], Train Loss: 0.1746, Valid Loss: 0.2696, Valid SSIM: 0.8674, Valid PSNR: 26.8340
# Epoch [377/2000], Train Loss: 0.1728, Valid Loss: 0.2681, Valid SSIM: 0.8647, Valid PSNR: 26.8568
# Epoch [378/2000], Train Loss: 0.1710, Valid Loss: 0.2890, Valid SSIM: 0.8595, Valid PSNR: 26.6084
# Epoch [379/2000], Train Loss: 0.1740, Valid Loss: 0.2654, Valid SSIM: 0.8664, Valid PSNR: 26.8011
# Epoch [380/2000], Train Loss: 0.1715, Valid Loss: 0.2792, Valid SSIM: 0.8679, Valid PSNR: 26.9203
# Epoch [381/2000], Train Loss: 0.1703, Valid Loss: 0.2779, Valid SSIM: 0.8662, Valid PSNR: 26.7251
# Epoch [382/2000], Train Loss: 0.1715, Valid Loss: 0.2748, Valid SSIM: 0.8630, Valid PSNR: 26.5467
# Epoch [383/2000], Train Loss: 0.1682, Valid Loss: 0.2682, Valid SSIM: 0.8694, Valid PSNR: 26.7968
# Epoch [384/2000], Train Loss: 0.1697, Valid Loss: 0.2695, Valid SSIM: 0.8675, Valid PSNR: 26.9949
# Epoch [385/2000], Train Loss: 0.1678, Valid Loss: 0.2732, Valid SSIM: 0.8677, Valid PSNR: 27.0014
# Epoch [386/2000], Train Loss: 0.1659, Valid Loss: 0.2686, Valid SSIM: 0.8693, Valid PSNR: 26.9706
# Epoch [387/2000], Train Loss: 0.1646, Valid Loss: 0.2701, Valid SSIM: 0.8649, Valid PSNR: 26.6719
# Epoch [388/2000], Train Loss: 0.1645, Valid Loss: 0.2673, Valid SSIM: 0.8677, Valid PSNR: 26.9289
# Epoch [389/2000], Train Loss: 0.1648, Valid Loss: 0.2755, Valid SSIM: 0.8674, Valid PSNR: 26.9036
# Epoch [390/2000], Train Loss: 0.1634, Valid Loss: 0.2632, Valid SSIM: 0.8640, Valid PSNR: 26.7659
# Epoch [391/2000], Train Loss: 0.1622, Valid Loss: 0.2689, Valid SSIM: 0.8705, Valid PSNR: 27.1100
# Epoch [392/2000], Train Loss: 0.1619, Valid Loss: 0.2768, Valid SSIM: 0.8656, Valid PSNR: 26.7422
# Epoch [393/2000], Train Loss: 0.1604, Valid Loss: 0.2607, Valid SSIM: 0.8715, Valid PSNR: 27.1281
# Epoch [394/2000], Train Loss: 0.1593, Valid Loss: 0.2682, Valid SSIM: 0.8686, Valid PSNR: 27.0426
# Epoch [395/2000], Train Loss: 0.1596, Valid Loss: 0.2615, Valid SSIM: 0.8705, Valid PSNR: 27.1275
# Epoch [396/2000], Train Loss: 0.1586, Valid Loss: 0.2652, Valid SSIM: 0.8689, Valid PSNR: 26.9510
# Epoch [397/2000], Train Loss: 0.1580, Valid Loss: 0.2682, Valid SSIM: 0.8706, Valid PSNR: 27.0885
# Epoch [398/2000], Train Loss: 0.1567, Valid Loss: 0.2708, Valid SSIM: 0.8691, Valid PSNR: 27.0011
#   2%|▏         | 16/797 [00:04<03:31,  3.68it/s]

# %%
# # Save the trained model
# torch.save(model.state_dict(), '../../Models/model.pth')

# %%
break

# %% [markdown]
# ## Prediction of cubes and evaluation

# %% [markdown]
# ## load the trained model

# %%
# model = HyperAttention(in_channels=3, out_channels=31).to(device).float()  # Adjust out_channels to match the target label size
# model.load_state_dict(torch.load('../Models/best_HyperAttention_fft.pth', map_location=device))
model.eval()

# %% [markdown]
# ## predict on a single file with the model

# %%
# image_path = "C:/Users/user/Desktop/HSI/dataset/ICASSP2024-SPGC/Hyper-Skin(RGB,VIS)/test/RGB_CIE/p012_neutral_front.jpg"
image_path = 'C:/Users/user/Desktop/Research/NTIRE_2022/NTIRE_2022/Test_RGB/ARAD_1K_0951.jpg'
image = Image.open(image_path)
plt.imshow(image)

# %%
image.size

# %%
# Define transformations to convert and preprocess the image
preprocess = transforms.Compose([
    transforms.Resize((512, 512)),  # Resize the image to match your model's input size
    transforms.ToTensor(),  # Convert the image to a PyTorch tensor
])

# Apply the transformations to the image
input_data = preprocess(image)

# Add an extra dimension to match the batch size (1 image in this case)
input_data = input_data.unsqueeze(0)

with torch.no_grad():
    input_data = input_data.to(device)
    output = model(input_data)
    
print('input data max',input_data.max())
print('input data min',input_data.min())
print(output.shape)
print('output max',output.max())
print('output min',output.min())

# %%
output

# %% [markdown]
# ## save .mat file

# %%
import h5py
import matplotlib.pyplot as plt

# Assuming 'output' is the result from your model and has shape [1, 31, 482, 512]
# Remove the batch dimension if it exists
if len(output.shape) > 3:
    output = output.squeeze(0)

num_channels = output.shape[0]
num_rows = 8  # You can adjust this based on your preference
num_cols = (num_channels + num_rows - 1) // num_rows  # Calculate the number of columns

plt.figure(figsize=(16, 12))  # Adjust the figure size as needed

for i in range(num_channels):
    plt.subplot(num_rows, num_cols, i + 1)
    channel_data = output[i].cpu().numpy()  # Convert the channel data to a NumPy array
    plt.imshow(channel_data, cmap='gray')  # Display the image in grayscale
    plt.title(f'Channel {i + 1}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# Define the path to the .mat file where you want to save the output as a cube
output_mat_file = "rgb_2.mat"  # Provide the desired file path

# Assuming 'output' is a PyTorch tensor
output_np = output.cpu().numpy()  # Convert the CUDA tensor to a NumPy array

# Create the .mat file using h5py and save the data without rotation
with h5py.File(output_mat_file, 'w') as mat_file:
    # Save the data without rotation
    mat_file.create_dataset('cube', data=output_np[0])  # Assuming you want to save the first element

# %% [markdown]
# ## load the output predicted .mat file

# %%
import h5py

# Define the path to the .mat file
mat_file_path = "rgb_2.mat"

# Open the .mat file using h5py
mat_contents = h5py.File(mat_file_path, 'r')

# Access the data by the key "cube"
cube_data = mat_contents["cube"]

# Convert the data to a NumPy array
output = cube_data[()]

# %% [markdown]
# ## visualize the predictions

# %%
import matplotlib.pyplot as plt
import numpy as np

# Check if the output has a batch dimension and remove it if it exists
if len(output.shape) > 3:
    output = output[0]

num_channels = output.shape[0]
num_rows = 8  # You can adjust this based on your preference
num_cols = (num_channels - 1) // num_rows + 1  # Calculate the number of columns

plt.figure(figsize=(16, 12))  # You can adjust the figure size as needed

for i in range(num_channels):
    plt.subplot(num_rows, num_cols, i + 1)
    channel_data = output[i]  # Use the NumPy array directly
    plt.imshow(channel_data, cmap='gray')
    plt.title(f'Channel {i + 1}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## bigger visulaization

# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np

# Define the path to the .mat file
mat_file_path = "rgb_2.mat"

# Open the .mat file using h5py
mat_contents = h5py.File(mat_file_path, 'r')

# Access the data by the key "cube"
cube_data = mat_contents["cube"]

# Convert the data to a NumPy array
output = cube_data[()]

# Check if the output has a batch dimension and remove it if it exists
if len(output.shape) > 3:
    output = output[0]

num_channels = output.shape[0]

# Set the figure size to display images in a single column
plt.figure(figsize=(6, 6 * num_channels))  # Adjust the height based on the number of channels

for i in range(num_channels):
    plt.subplot(num_channels, 1, i + 1)  # Display images in a single column
    channel_data = output[i]  # Convert the tensor to a NumPy array
#     channel_data = np.rot90(channel_data, k=3)  # Rotate counterclockwise by 90 degrees
    plt.imshow(channel_data, cmap='gray', origin='upper')  # Specify origin='upper' to prevent rotation
    plt.title(f'Channel {i + 1}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## predictions on all test images

# %%
# import os
# from PIL import Image
# import torch
# import torchvision.transforms as transforms
# import h5py
# import numpy as np

# model = HyperAttention(in_channels=4, out_channels=61).to(device).float()  # Adjust out_channels to match the target label size
# model.load_state_dict(torch.load('../Models/Aug_HyperAttention_fft_470e.pth'))
# model.eval() 

# input_folder = "../Dataset/ICASSP2024-SPGC/Hyper-Skin(MSI,NIR)/test/MSI_CIE" # Replace this with the path the input test folder
# output_folder = "./output/Aug_HyperAttention_fft_470e" # Replace with the path to your output folder

# # Make sure the output folder exists
# os.makedirs(output_folder, exist_ok=True)

# # Define the preprocessing transformation
# preprocess = transforms.Compose([
#     transforms.Resize((1024, 1024)),
#     transforms.ToTensor(),
# ])

# # Loop through all the image files in the input folder
# for filename in os.listdir(input_folder):
#     if filename.endswith(".mat"):  # Assuming you have .mat files for 4-channel input
#         # Load the .mat file
#         mat_file_path = os.path.join(input_folder, filename)

#         # Load the .mat file using h5py
#         mat_file = h5py.File(mat_file_path, 'r')

#         # Access and load the 'cube' dataset
#         input_data = mat_file['cube']  # Use the correct dataset name

#         # Convert the data to a NumPy array
#         input_data = np.array(input_data)

#         # Convert the NumPy array to a PyTorch tensor
#         input_data = torch.from_numpy(input_data)

#         # Add an extra dimension to match the batch size (1 image in this case)
#         input_data = input_data.unsqueeze(0)

#         # Ensure that the input data and model have the same data type
#         input_data = input_data.to(device).float()

#         with torch.no_grad():
#             # Get model predictions
#             output = model(input_data)

#         # Create the output .mat file
#         output_mat_file = os.path.join(output_folder, os.path.splitext(filename)[0] + ".mat")

#         # Convert the output to a NumPy array
#         output_np = output.cpu().numpy()  # Move the output to the CPU and then convert to NumPy

#         # Save the data as a .mat file
#         with h5py.File(output_mat_file, 'w') as mat_file:
#             mat_file.create_dataset('cube', data=output_np[0])

#         print(f"Processed {filename} and saved as {os.path.basename(output_mat_file)}")

# %% [markdown]
# ## val sam calculation

# %%
import torch
import math
from piq import ssim

criterion = SAMLoss()
# Define the RMSE Loss Function
def rmse_loss(outputs, targets):
    mse = torch.mean((outputs - targets) ** 2)
    rmse = torch.sqrt(mse)
    return rmse

# Define the PSNR Loss Function
def psnr_loss(outputs, targets, max_pixel=1.0):  # Assuming normalized data [0, 1]
    mse = torch.mean((outputs - targets) ** 2)
    if mse == 0:
        return float('inf')
    psnr = 20 * math.log10(max_pixel) - 10 * math.log10(mse)
    return psnr

# Assuming the model is already in evaluation mode and loaded
model.eval()

# Initialize variables to store total losses
total_sam_loss = 0.0
total_ssim = 0.0
total_rmse = 0.0
total_psnr = 0.0

with torch.no_grad():
    for batch_idx, (x_val, y_val) in enumerate(valid_loader):
        x_val, y_val = x_val.to(device).float(), y_val.to(device).float()

        # Forward pass
        outputs_val = model(x_val)

        # Ensure output size matches target size
        outputs_val = torch.nn.functional.interpolate(outputs_val, size=y_val.shape[2:], mode='bilinear', align_corners=False)

        # Min-max normalization for outputs and targets
        outputs_val_norm = (outputs_val - outputs_val.min()) / (outputs_val.max() - outputs_val.min() + 1e-8)
        y_val_norm = (y_val - y_val.min()) / (y_val.max() - y_val.min() + 1e-8)

        # Calculate losses
        sam_loss = criterion(outputs_val_norm, y_val_norm)
        ssim_val = ssim(outputs_val_norm, y_val_norm, data_range=1.0)
        rmse_val = rmse_loss(outputs_val_norm, y_val_norm)
        psnr_val = psnr_loss(outputs_val_norm, y_val_norm)

        # Accumulate the total losses
        total_sam_loss += sam_loss.item()
        total_ssim += ssim_val.item()
        total_rmse += rmse_val.item()
        total_psnr += psnr_val

# Calculate the average losses over all batches
avg_sam_loss = total_sam_loss / len(valid_loader)
avg_ssim = total_ssim / len(valid_loader)
avg_rmse = total_rmse / len(valid_loader)
avg_psnr = total_psnr / len(valid_loader)

# Print the average losses
print(f"Average SAM Loss: {avg_sam_loss:.4f}")
print(f"Average SSIM: {avg_ssim:.4f}")
print(f"Average RMSE: {avg_rmse:.4f}")
print(f"Average PSNR: {avg_psnr:.4f}")

# %%
# Assuming model is already loaded and in evaluation mode
model.eval()
criterion = SAMLoss()

# Define a variable to store the total loss
total_val_loss = 0.0

# Iterate over the validation loader
with torch.no_grad():
    for batch_idx, (x_val, y_val) in enumerate(valid_loader):
        x_val, y_val = x_val.to(device).float(), y_val.to(device).float()

        # Forward pass
        outputs_val = model(x_val)
        
        # You may need to apply the same interpolation to outputs_val as in the training loop
        outputs_val = torch.nn.functional.interpolate(outputs_val, size=(482, 512), mode='bilinear', align_corners=False)

        # Calculate the loss
        val_loss = criterion(outputs_val, y_val)

        # Accumulate the total loss
        total_val_loss += val_loss.item()

# Calculate the average validation loss
avg_val_loss = total_val_loss / len(valid_loader)

# Print or use the average validation loss as needed
print(f"Average Validation Loss: {avg_val_loss:.4f}")

# %% [markdown]
# ## train sam loss

# %%
# Assuming model is already loaded and in evaluation mode
model.eval()
criterion = SAMLoss()
# Define a variable to store the total loss
total_train_loss = 0.0

# Iterate over the training loader
with torch.no_grad():
    for batch_idx, (x_train, y_train) in enumerate(train_loader):  # Use train_loader instead of val_loader
        x_train, y_train = x_train.to(device).float(), y_train.to(device).float()

        # Forward pass
        outputs_train = model(x_train)
        
        # You may need to apply the same interpolation to outputs_train as in the training loop
        outputs_train = torch.nn.functional.interpolate(outputs_train,size=(482, 512), mode='bilinear', align_corners=False)

        # Calculate the loss
        train_loss = criterion(outputs_train, y_train)

        # Accumulate the total loss
        total_train_loss += train_loss.item()

# Calculate the average training loss
avg_train_loss = total_train_loss / len(train_loader)

# Print or use the average training loss as needed
print(f"Average Training Loss: {avg_train_loss:.4f}")

# %%
# Assuming the model is in evaluation mode and loaded
model.eval()

# Initialize variables to store total losses for training data
total_sam_loss_train = 0.0
total_ssim_train = 0.0
total_rmse_train = 0.0
total_psnr_train = 0.0

with torch.no_grad():
    for batch_idx, (x_train, y_train) in enumerate(train_loader):
        x_train, y_train = x_train.to(device).float(), y_train.to(device).float()

        # Forward pass
        outputs_train = model(x_train)

        # Ensure output size matches target size
        outputs_train = torch.nn.functional.interpolate(outputs_train, size=y_train.shape[2:], mode='bilinear', align_corners=False)

        # Min-max normalization for outputs and targets
        outputs_train_norm = (outputs_train - outputs_train.min()) / (outputs_train.max() - outputs_train.min() + 1e-8)
        y_train_norm = (y_train - y_train.min()) / (y_train.max() - y_train.min() + 1e-8)

        # Calculate losses
        sam_loss_train = criterion(outputs_train_norm, y_train_norm)
        ssim_train = ssim(outputs_train_norm, y_train_norm, data_range=1.0)
        rmse_train = rmse_loss(outputs_train_norm, y_train_norm)
        psnr_train = psnr_loss(outputs_train_norm, y_train_norm)

        # Accumulate the total losses for training data
        total_sam_loss_train += sam_loss_train.item()
        total_ssim_train += ssim_train.item()
        total_rmse_train += rmse_train.item()
        total_psnr_train += psnr_train

# Calculate the average losses over all training batches
avg_sam_loss_train = total_sam_loss_train / len(train_loader)
avg_ssim_train = total_ssim_train / len(train_loader)
avg_rmse_train = total_rmse_train / len(train_loader)
avg_psnr_train = total_psnr_train / len(train_loader)

# Print the average losses for training data
print(f"Average SAM Loss on Training Data: {avg_sam_loss_train:.4f}")
print(f"Average SSIM on Training Data: {avg_ssim_train:.4f}")
print(f"Average RMSE on Training Data: {avg_rmse_train:.4f}")
print(f"Average PSNR on Training Data: {avg_psnr_train:.4f}")
